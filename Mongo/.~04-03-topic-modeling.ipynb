# %%
import pandas as pd
import random

from mongo_aggregation_verbs import *

from lib import create_mongo_client_to_database_collection

collection_reference = create_mongo_client_to_database_collection('twitter', 'tweets')

# %% [markdown]
# - https://alexisperrier.com/nlp/2015/09/16/segmentation_twitter_timelines_lda_vs_lsa.html
# - https://alexisperrier.com/nlp/2015/09/04/topic-modeling-of-twitter-followers.html

# %%
match_empty_url_arrays = { MATCH : { "entities.urls" : [] } }

list(collection_reference.aggregate(
    [
        match_empty_url_arrays,
        { COUNT : "text" }
    ]
))
# Out:
# [{'text': 197408}]

# %%
job_hashtags = ['job', 'jobs', 'hiring', 'careerarc']
location_hashtags = ['california', 'losangeles', 'la', 'santamonica', 'glendale', 'paloalto']
match_not_in_bad = { MATCH : { "text" : { "$in" : job_hashtags + location_hashtags } } }
project_to_text_keep_id = { PROJECT : { "text" : "$entities.hashtags.text" } }
project_to_id = { PROJECT : { "_id" : 1 } }

bad_ids = list(collection_reference.aggregate(
    [
        match_non_empty_hashtag_arrays,
        project_to_text_keep_id,
        unwind_text,
        project_to_lower,
        match_not_in_bad,
        project_to_id
    ]
))
bad_ids[:10], len(bad_ids)
# Out:
# ([{'_id': ObjectId('5b568e378c4e2000a5220167')},
#   {'_id': ObjectId('5b569cc0987491012707420a')},
#   {'_id': ObjectId('5b569cc09874910127074228')},
#   {'_id': ObjectId('5b569cc09874910127074228')},
#   {'_id': ObjectId('5b569cc09874910127074228')},
#   {'_id': ObjectId('5b56a9261a6d22025b8bfd5b')},
#   {'_id': ObjectId('5b56a9a01a6d22025b8bff7f')},
#   {'_id': ObjectId('5b56a9ad1a6d22025b8bffbb')},
#   {'_id': ObjectId('5b56a9c81a6d22025b8c0047')},
#   {'_id': ObjectId('5b56aa001a6d22025b8c014d')}],
#  9498)

# %%
bad_ids = [bad_id['_id'] for bad_id in bad_ids]
bad_ids[:10]
# Out:
# [ObjectId('5b568e378c4e2000a5220167'),
#  ObjectId('5b569cc0987491012707420a'),
#  ObjectId('5b569cc09874910127074228'),
#  ObjectId('5b569cc09874910127074228'),
#  ObjectId('5b569cc09874910127074228'),
#  ObjectId('5b56a9261a6d22025b8bfd5b'),
#  ObjectId('5b56a9a01a6d22025b8bff7f'),
#  ObjectId('5b56a9ad1a6d22025b8bffbb'),
#  ObjectId('5b56a9c81a6d22025b8c0047'),
#  ObjectId('5b56aa001a6d22025b8c014d')]

# %%
not_in_bad_ids = { "$nin" : bad_ids }

# %%
not_in_bad_ids_and_no_url = { 
    "_id"           : not_in_bad_ids, 
    "entities.urls" : []
}

just_the_text = {
    "text" : 1,
    "_id"  : 0
}

# %%
collection_reference.find_one(
    not_in_bad_ids_and_no_url,
    just_the_text
)
# Out:
# {'text': 'Can’t wait to go home and play video games already smh'}

# %%
cur  = collection_reference.find(
    not_in_bad_ids_and_no_url,
    just_the_text
)

tweets = list(cur)
tweet_text = pd.DataFrame(tweets)

# %%
tweets
# Out:
# [{'text': 'Can’t wait to go home and play video games already smh'},
#  {'text': 'Can’t wait to go home and play video games already smh'},
#  {'text': 'ya https://t.co/ZOjRvdvOFB'},
#  {'text': 'Let’s go #Dodgers'},
#  {'text': '“Chunky peanut butter is rough on the teeth, lemme go smooth for a minute”-Me talking about my 30s'},
#  {'text': 'https://t.co/y9gmXXMmWs'},
#  {'text': "Another shit show!! \nGO O'S!!\n#DeadBirds"},
#  {'text': '@SPRinNYC Me, a Capricorn.'},
#  {'text': 'ya https://t.co/ZOjRvdvOFB'},
#  {'text': 'Let’s go #Dodgers'},
#  {'text': '“Chunky peanut butter is rough on the teeth, lemme go smooth for a minute”-Me talking about my 30s'},
#  {'text': 'https://t.co/y9gmXXMmWs'},
#  {'text': "Another shit show!! \nGO O'S!!\n#DeadBirds"},
#  {'text': '@SPRinNYC Me, a Capricorn.'},
#  {'text': 'ya https://t.co/ZOjRvdvOFB'},
#  {'text': '@TheRynheart Kookoo'},
#  {'text': '@The_Trump_Train @realDonaldTrump We need candidates that put Russia first, not America first! Oh wait....'},
#  {'text': "I'm going through a lot right now...."},
#  {'text': 'https://t.co/W6O4eqt8Li'},
#  {'text': 'There’s nothing I want to do more than to sleep this sickness off but unfortunately I have to edit 😭 https://t.co/wKtYeYenWN'},
#  {'text': "There's a pile of shit on the table at work. It's a metaphor."},
#  {'text': '5년간 23조 쓰고 4대강 보 남긴 이명박과 13개월간 34조 쓰고 최악의 실업률, 물가폭동 남긴 문재인 이 두분 중 만약 형무소를 보낸다면 누구를 보내야 옳을까요?(Yeong \nKook Jeong)'},
#  {'text': '@_MartinWeiss Please use it in a sentence'},
#  {'text': '@jackeryinc I would use Jackery products in Joshua Tree and at the beach!.'},
#  {'text': '@arboldepaz La parte final es la más graciosa. Es que cortar leña tiene su truco.'},
#  {'text': '@bryadee_ Damn man that mean imma have to fight 😭'},
#  {'text': 'Defintion of a lil bitch https://t.co/PREOcFDBHq'},
#  {'text': '@jessiekaiser @JoseyPickering @pansaralance'},
#  {'text': 'RAWAYANA PA EL ALMA Y CULTURA PROFETICA PA LA MENTE... ESPERANDO CON GANAS EL 1 DE SEPTIEMBRE.🤗'},
#  {'text': 'Zooted is such a catchy song 😭'},
#  {'text': '@HardWay511 @WayneDupreeShow @Cameron13602482 Right?!'},
#  {'text': 'Omg I can’t believe Vicki did that to Kelly. Ummmm girl code much? #RHOC 😦🍊'},
#  {'text': 'This theater is packed. There are lot of people waiting in line. No more seat left.'},
#  {'text': '@Jeff_in_3D @Gloudas_ @thadarkman78 But then you didn’t LOL'},
#  {'text': 'Lmfaoo ima mind my business'},
#  {'text': '@KTLA @SFBART 👏🏽'},
#  {'text': '@SeeTheRoses Yes, because it is so quiet, it is the perfect environment to absorb any and every Audio sound available at the moment.'},
#  {'text': '@RHeathervaughn Exactly. He’s the grim reaper with a looong red tie.'},
#  {'text': '@wtvzaa Me!'},
#  {'text': '@DanielGordon1 @leguilloux 😅'},
#  {'text': "[단독] 이삿짐처럼 증거 옮긴 드루킹 일당..경찰은 '수수방관'5t짜리 이삿짐 트럭 1대가 창고 단지로 들어오는 모습입니다. 잠시 뒤 잡동사니를 가득 실은 트럭과 함께 또 다른 이삿짐 트럭이 들어섭니다.(안상우)"},
#  {'text': 'I really want to take my hair down'},
#  {'text': 'Shasta High School has been set up as an evacuation Center for the #CarrFire for those evacuating east.'},
#  {'text': "@EmilyCWaldon @dennistlin Is it sad that I'm not even surprised? https://t.co/ksg3AhNB7Y"},
#  {'text': '@longdrivesouth And, in Spanish, it already is.'},
#  {'text': '지난달 15일, 드루킹 일당은 느릅나무 출판사에 남아 있던 물품들을 근처 컨테이너 창고로 옮겼습니다.이틀에 걸쳐 옮겼는데 이삿짐 트럭으로 8대, 상자 950개 분량이었습니다.(안상우)'},
#  {'text': 'LEG DAY !!!!!'},
#  {'text': '@chucky_beatz @JoeyFatts lmfao'},
#  {'text': 'I’m going to be one of the greatest to ever do'},
#  {'text': '@TeamQuesoGG @Gamepolis_org Tras un breve viaje todo bien gracia por preguntar'},
#  {'text': 'Trevor Lee coming into BOLA 2018. #pwg https://t.co/bzmjByGRI7'},
#  {'text': '@redroses618 I try. \nLove poetry is my next-best specialty. \nDark poetry is what I am best at!'},
#  {'text': 'https://t.co/7sJSBvK3rQ'},
#  {'text': 'I’m going to be one of the greatest to ever do'},
#  {'text': '@I_JEDI Hater of broccoli? Idiot'},
#  {'text': 'https://t.co/D4bTQKXi9Y'},
#  {'text': '@yvonne_pacheco @DerickMorales45 Soraya would disagree too'},
#  {'text': '@jfcmang @darrenrue @whatisnudoin i rocking with darren on this one, tyreke evans shit was crazy too'},
#  {'text': '@SarahPalinUSA SMH 🤦\u200d♂️'},
#  {'text': 'https://t.co/dFzhZbgokQ'},
#  {'text': '@CarlosE_Lozada Todo es posible en la dimensión desconocida.'},
#  {'text': '@DeZoN_JaMeS So pretty much control ur self stupid'},
#  {'text': '@virginiatodd Thank you!'},
#  {'text': 'Yesterday’s shoot was a success! 3 videos in one night. On to the next night 1AM-6AM 🎥 💪'},
#  {'text': 'Census Tract 2754, Los Angeles County, California https://t.co/JvT8tyIJAC'},
#  {'text': 'I’m so hyped that I can finally get my nails done 😭'},
#  {'text': '@rubithecat Thank you!!'},
#  {'text': '@Floorman_Alan @HUSTLERCASINOLA How many through E? And what’s the payout structure of d2/3 look like?'},
#  {'text': '@RichSqueezy #GingerDookies'},
#  {'text': 'To me &amp; I’m sure members of Raider Nation everywhere, Greg Papa is the voice of the Silver &amp; Black. Always will be.'},
#  {'text': '양승태를 죽일려는 이유가 "통진당 해산" "이석기 실형" 때문에 통진당 잔당넘들이 만든거네 알만하지 이것들이 뭘 못하겠어 그러니 전문 시위꾼들 동원해서 양승태 구속 이석기 석방을 외치지 아주 충신 났다(문간첩탄핵하자)'},
#  {'text': 'I’m single and I’m still probably getting cheated on😭'},
#  {'text': 'I needs uh boppaleany'},
#  {'text': '@JNICOLE_____ Might work for ladies too lmao. Imma sure try it 😂😂😂'},
#  {'text': "@mantis915 Yeah, but everyone knows places like Newark and LAX are shitty. Nobody ever mentions Philly and it's a major city."},
#  {'text': '@MSchwartz3 And what about those easily fooled by the shiny objects?'},
#  {'text': '@beingalifunez Yum I want some now'},
#  {'text': '@DonaldHermann It is the look of LOVE!! 😍 Lol'},
#  {'text': '@OjaruFan @laemmle No spoilers here. Please join us to solve the mystery! 😁'},
#  {'text': '@desjaisaiah love you😘'},
#  {'text': 'People who work at comic book stores are relentlessly cool'},
#  {'text': '🤔🤔 https://t.co/wCw7Ijt82W'},
#  {'text': '우리나라가 북한을 따라 공공의 적으로 가고 있음. 유엔 “북한 석탄, 한국서 환적”…석탄세탁에 한국 이용 확인(엘렐레)'},
#  {'text': '@HMLoeschMcK @beth2_k3 Throw in the Mena Connection...😏'},
#  {'text': '@honeymiryI 👀'},
#  {'text': 'Hey @vgdunkey bojack dunksman'},
#  {'text': '“fuck you mom“ will become an acceptable household term after online gaming becomes an olympic in event in 2036'},
#  {'text': '박근혜 대통령 탄핵이 기각되면 혁명도 불사하겠다는 문재인의 내란기획도 수사하라 !(Freedoms  Guardian)'},
#  {'text': 'I gotta do something for my own personal business I can still handle that.'},
#  {'text': 'Jerry Remy says this is the best Red Sox outfield he’s ever seen\n\nAnd Jerry Remy has seen some shit, man'},
#  {'text': '@_littlejayy What a handsome baby omg 😍😍😍'},
#  {'text': '단독] 조현천 "내가 계엄령 검토 지시..조사 받겠다"\n새로워진 뉴스데스크, 첫 소식은 기무사의 계엄령 문건 관련 단독 보도로 시작합니다. .(조국현)'},
#  {'text': '@keepinupwitkd The biggest bully 😭😭 jk jk I know you sweet just be getting provoked'},
#  {'text': '@02Benson I feel the last part was directed at me... https://t.co/Scq3578lrV'},
#  {'text': '@RottenTomatoes #SHAZAMMovie'},
#  {'text': 'Mi sueño es comprarle una casa a mi mama.'},
#  {'text': '문건이 만들어질 당시 조현천 기무사령관이 최근 계엄령 문건은 내가 만들라고 지시했다고 말한 사실이 확인됐습니다.상부의 지시도, 하부의 제안도 아닌 기무사령관 자신이 직접 제안해 지시했다는 겁니다.(조국현)'},
#  {'text': '@Guarromantico_ @brandonbarba_  take note bae'},
#  {'text': 'This. Tag. Match. 🔥🔥🔥\n\n#RAW'},
#  {'text': 'I’m staaaaaaaaarving!!! 😫 suggestions on what to eat anyone???'},
#  {'text': "@YokaiWatchNews It's also 'Shark Week,' right?"},
#  {'text': '@teachergoals On it!  Thanks for the reminder.'},
#  {'text': 'Pride is a bitch.'},
#  {'text': '청와대가 수사기관인가? 그렇다면 反軍선동세력부터 엄단하라! \n이 세상에 쿠데타를 계획한 문건을 보존하였다가 다음 정권에 넘기는 경우도 있나? 戰時엔 국군이 국민을 지켜주지만 平時엔 국민이 국군을 지켜주어야 한다! (국민행동본부)'},
#  {'text': 'Funny how shady family can really be..'},
#  {'text': 'Fuckkkk I got the chills 😵'},
#  {'text': 'Hispanic parents think that everything that happens in La Rosa de Guadalupe is gonna happen to us 🙄 we’re not that stupid...'},
#  {'text': 'Twin Peaks and a 12 hour travel time. Let’s do this, I guess. I’m off to melt my brain. Peace. ✌🏻'},
#  {'text': '@EricTo3pp You should just always be embarrassed about yourself'},
#  {'text': '@GrimmBig that allergic shit don’t stop nothing but my breathing😤💪🏽💯'},
#  {'text': 'Mi sueño es comprarle una casa a mi mamá.'},
#  {'text': '2. 수사단 편성에서 육군을 제외시킨 행위는 문제가 크다. 김재규가 대통령을 시해하였다고 합동수사단에서 김씨를 뺀 적이 없다. 군을 육군과 非육군으로 차별하면 군대가 敵前(적전)분열한다. (국민행동본부)'},
#  {'text': '@Jeff_in_3D @Gloudas_ @thadarkman78 LOL you stalked me'},
#  {'text': '@Paula_White Make sure you let the Refugees that trump took their kids away and has them in cages, no that!!'},
#  {'text': 'Welp Cali it’s been mf reaaaaal. 💕 and of course I’ll be back soon 😘'},
#  {'text': 'i wish it was easier for me to just say what’s really on my mind'},
#  {'text': '3. 왜 ‘촛불 계엄령’이라고 왜곡하나? 기무사 계엄령 검토문건은 촛불 시위와 태극기 시위 양쪽의 폭력화 가능성을 공평하게 언급하였는데 마치 촛불시위대를 탄압하려 했다는 선동적 표현이다. (국민행동본부)'},
#  {'text': '4. 구체적 수사에 간여할 수 없는 대통령이 왜 국방장관을 무시하고 직접 수사 지침까지 내리나? 독립수사단은 법적 근거가 없다. 무리하면 ‘쿠데타 조작 사건’으로 기록될 것이다. (국민행동본부)'},
#  {'text': 'my venmo is @ taylor-jewell-1 for anyone who wanna donate to my D&amp;G lovepill fund @robber0540 plz'},
#  {'text': '😂😂😂😂😂😂😂😂😂😂😂 https://t.co/htLexE9a6o'},
#  {'text': '@MaryJo44966098 Awww Thank you 😘'},
#  {'text': 'brooo the salads from Mezzo be making my jaw tired from all the chewing'},
#  {'text': 'this man eats ice cream with his chicken.......'},
#  {'text': '@rayvolpe ya'},
#  {'text': 'Delete my number if all you’re gonna do is hit me every other day with some “what you doing?” Bullshit bitxh'},
#  {'text': '@lasteve423 But of course!! That’s my problem with #HandmaidsTale - authoritarianism is racism, but not on the show.'},
#  {'text': '5. 국방장관도 수개월 전에 보고를 받고 범죄혐의가 없다는 판단을 했다는데 누가 대통령에게 다른 판단을 해 보고하였나? 허위보고로 해외에 가 있는 대통령을 함정에 빠뜨린 것이 아닌가? (국민행동본부)'},
#  {'text': '@NBCSports 11 @PGATOUR wins in a row. 18 wins in 1 season. Take your pick? Both done by Byron Nelson.'},
#  {'text': '@realDonaldTrump You’s a hoe'},
#  {'text': '6. 계엄령 검토 문건 작성은 국방부 공개회의에서 논의되고 문건도 보존하였다. 이 세상에서 쿠데타를 공개적으로 논의하고 계획서를 다음 정권에 인계하는 경우도 있나? (국민행동본부)'},
#  {'text': 'Damn Fifty straight taking a Fat L to Floyd lol #fiftycent #FloydMayweather'},
#  {'text': 'Orioles have outhit the Red Sox 7-5\n\nRed Sox have outscored the Orioles 5-0'},
#  {'text': 'Sorry that I care about people who are locked up, you probably should too. #SorryNotSorry'},
#  {'text': '╔═╗\n║╔╝\n║╚╗\n╚═╝\n╔╦╗\n║║║\n║║║\n╚═╝\n╔═╦═╗\n║║║║║\n║║║║║\n╚╩═╩╝\n╔══╗\n║╔╗║\n║╔╗║\n╚══╝\n╔══╗\n╚║║╝\n╔║║╗\n╚══╝\n╔══╗\n║╔╗║\n║╠╣║\n╚╝╚╝\n╔══╗\n║══╣\n╠══║\n╚══╝\n😃💃🕺🤳'},
#  {'text': '@AlanCruz @_AshleeDoty Number 5 definitely'},
#  {'text': '@memoo24_ @oscarg_21  https://t.co/NCjoiX3me8'},
#  {'text': 'i feel bad for mfs who don’t like seafood cuz y’all niggas definitely missing out'},
#  {'text': 'Watching drama is all fun n games til it hit yo circle 😭😭'},
#  {'text': '😴 https://t.co/WjuXx1Cbxg'},
#  {'text': 'can you believe this is Jen’s first time on a unicycle? https://t.co/c5Je25pdAy'},
#  {'text': "I'm really looking forward to going to the beach and seeing somebody's summer face and booty melt off."},
#  {'text': '@rskaziak Yes, the sequel is done and #MurderFunding will be out next year! And YAY for a Code Monkeys fan!'},
#  {'text': '@OfficialPWG  https://t.co/uJkDVtNNz4'},
#  {'text': '@Education4Libs 👍🏻👍🏻💯'},
#  {'text': '7. 최근 反軍(반군)세력이 선동언론과 짜고 쿠데타 운운하니 청와대 비서실이 호응한 것으로 보인다. 反軍선동에 정권이 가담하면 나라가 유지되나? (국민행동본부)'},
#  {'text': '@RichSqueezy Fawkn animals...\n\nU comin to the show tmrw'},
#  {'text': '@KimDotcom @JudicialWatch DO IT ✔️'},
#  {'text': 'Man I wanna go to hard jus to see Cupcakke. Lol'},
#  {'text': 'TEST_GEO_Hierarchy: 5d6fcd0f-f56f-4688-b0a5-951ed292fb09'},
#  {'text': 'TEST_GEO_Hierarchy: 0756679b-0cc4-4528-bc75-e1cf2f08dc74'},
#  {'text': 'How is deGrom 5-5 with an ERA well south of 2?!'},
#  {'text': '"It takes longer than you think to write a good tweet," I pomped at the kid as I looked down to realize I hadn\'t attached the photo'},
#  {'text': 'verdugo’s first at bat after being called up and he has to face seranthony dominguez'},
#  {'text': '🤑 https://t.co/IuDhHdGgw7'},
#  {'text': '@BillRosemann @MarvelChampions @Marvel @MarvelGames Best storyline was always between she and Rogue.'},
#  {'text': '@CarlosE_Lozada Todo es posible en la dimensión desconocida.'},
#  {'text': '@DeZoN_JaMeS So pretty much control ur self stupid'},
#  {'text': 'Census Tract 2754, Los Angeles County, California https://t.co/JvT8tyIJAC'},
#  {'text': '8. 헌법 제5조는 국토방위뿐 아니라 국가안전보장을 국군의 신성한 의무로 규정하였다. 국가질서가 붕괴되었을 때 국무회의와 대통령의 결정에 따라 국군이 질서 유지 차원에서 출동하는 것은 헌법상의 의무 이행인데'},
#  {'text': '@CryptoWildWest This is exactly what I was talking about. I see these opportunities regularly, but I’m not confident in my strategy yet'},
#  {'text': '@GoddessVienna @SextPanther Actually kinda hot.'},
#  {'text': 'IM SO SICK AND FUCKEN TIRED OF PEOPLES BULLSHIT'},
#  {'text': 'Dad level approaching dangerous new heights... https://t.co/aKHaHjX5xP'},
#  {'text': '이를 쿠데타로 모는 자가 있다. 좌익이 폭동할 때 군대가 구경만 하도록 함으로써 반공자유민주주의 체제가 무너지도록 하기 위한 예행연습 아닌가? (국민행동본부'},
#  {'text': '@superNATorious @Perrico_Querico I shit you not it only looks like this on camera, in person it’s like white/gray LOL'},
#  {'text': '@blueauthority Ojalá.'},
#  {'text': '@Stammy @googlephotos damn. this is incredible'},
#  {'text': 'You can support black women and \nFuck white girls \nDon’t let anybody tell u different brother'},
#  {'text': '@C_3C_3 The assertion that he was coordinating with the Russians was an outright lie. Without that lie the warrant would have been denied.'},
#  {'text': '9. 이왕 수사단이 만들어졌으니 가장 먼저 이 문건의 유출경위를 조사하여 엄단하라!10. 戰時(전시)에는 국군이 국민을 보호하지만 平時(평시)엔 국민이 국군을 지켜\n야 한다. ‘국군을 모독하는 불순세력’으로부터 국군을 지키자! (국민행동본부)'},
#  {'text': '@jfrosh_10 Slap yourself'},
#  {'text': '@WhoopiGoldberg \n\nChose #Love https://t.co/8CaqYlDiUB'},
#  {'text': '@michaelgat Omagosh!'},
#  {'text': 'mexican dads at the grocery store will never not try &amp; school me on beer at the beer aisle'},
#  {'text': '@JizzaRaw ahhh thank you!'},
#  {'text': '@BackTheCops 🙏'},
#  {'text': 'Another season of Nikki being the prettiest one. #LHHH https://t.co/h1wS7j5C2b'},
#  {'text': '@dopeiamana @JaimesSthp JAJAJAJAJAJAJA “ese no es el que nos iba levar?!?” Ya bien pedo 😂😂😂'},
#  {'text': '@jfcmang @darrenrue @whatisnudoin i rocking with darren on this one, tyreke evans shit was crazy too'},
#  {'text': 'There’s literally a shirtless crazy dude on this train pacing around and yet @metrolosangeles is doing nothing???? SHOCKER'},
#  {'text': '“seems like everybody is a dick without you baby”'},
#  {'text': 'not dead just ignoring you lol'},
#  {'text': 'My favorite character of #RHONY is sober Luanne in that wig and my favorite character of #RHOC is Shannon’s dog.'},
#  {'text': '@dukhanomore @Carola2hope Comenzaré pronto.'},
#  {'text': "@ispypanda You have to win me first. \nAnd I'm not an easy prize to get. \nBut if you do... \nyou'll get a prize well worth  keeping."},
#  {'text': 'i’m hungry'},
#  {'text': '@adorabobo agot have u gone to an gs open practice, asking for science'},
#  {'text': '@SarahPalinUSA SMH 🤦\u200d♂️'},
#  {'text': 'I got really happy because I thought Castle Rock came out today but no it comes out Wednesday. #ugh'},
#  {'text': 'Idgaf about nothing rn on god I wanna slap a bitch into next week'},
#  {'text': '@Novaesoul @EmilyRB @MissyElspeth 💔💔💔'},
#  {'text': '@avalonwillows I’m so sorry'},
#  {'text': '@bigmike88283166 @jorse2646 @ducksfan2007 @SEX_Overlord @VNAgirls Thank you'},
#  {'text': '@hormiga 1 + 2 = Hamster 🐹 ?'},
#  {'text': '@bigmike88283166 @jorse2646 @ducksfan2007 @SEX_Overlord @VNAgirls Thank you'},
#  {'text': '@Novaesoul @EmilyRB @MissyElspeth 💔💔💔'},
#  {'text': 'I’m that fucker that knows he the best as what he does , ain’t no one better !'},
#  {'text': '@LeftSentThis I hope they fry this creep'},
#  {'text': 'https://t.co/kVHmZZsQ9k'},
#  {'text': '"In theory, there is no difference between theory and practice. In practice there is." ~ Yogi Berra'},
#  {'text': 'listening to Christmas music and dancing alone in my underwear 4ever'},
#  {'text': '@bigmike88283166 @jorse2646 @ducksfan2007 @SEX_Overlord @VNAgirls Thank you'},
#  {'text': '@Novaesoul @EmilyRB @MissyElspeth 💔💔💔'},
#  {'text': 'I’m that fucker that knows he the best as what he does , ain’t no one better !'},
#  {'text': '@LeftSentThis I hope they fry this creep'},
#  {'text': 'https://t.co/kVHmZZsQ9k'},
#  {'text': '"In theory, there is no difference between theory and practice. In practice there is." ~ Yogi Berra'},
#  {'text': 'listening to Christmas music and dancing alone in my underwear 4ever'},
#  {'text': '@teddy2_ @OTS_Mortem bet'},
#  {'text': '@tatyanaluvscats Hot pic but sis, this is a clusterfuck of a post lmao.'},
#  {'text': 'TEST_GEO_Hierarchy: 448bf2f4-7bf5-4695-88ac-e16a8e99f476'},
#  {'text': 'TEST_GEO_Hierarchy: 4c9ac74d-5c5b-4542-bb40-4c32580c3fcf'},
#  {'text': 'I hope my senior year is good to me 🙏🏽'},
#  {'text': '@cry_baby_britt  https://t.co/TWBiF8Nv09'},
#  {'text': '@CrucialxJess Did you eat it?'},
#  {'text': 'Severe Thunderstorm Warning continues for Montague CA, Grenada CA until 9:00 PM PDT https://t.co/Y18SPMMsBN'},
#  {'text': '@Brasilmagic @lough_sydney me too! https://t.co/0SgZ6Teo3Z'},
#  {'text': '@MonstersOfRock 🤘🏽'},
#  {'text': 'twitter making me feel lonely n shit'},
#  {'text': 'will you be mine &amp; come be with me?'},
#  {'text': '@artiequitter @sternshow @SIRIUSXM You don’t find this interesting Art?'},
#  {'text': '@DarwinBondGraha @CLang_2883'},
#  {'text': "@NW360TheGamer They are, they also have a lot of modes that don't use it. So it's pretty nice :D"},
#  {'text': '8. 헌법 제5조는 국토방위뿐 아니라 국가안전보장을 국군의 신성한 의무로 규정하였다. 국가질서가 붕괴되었을 때 국무회의와 대통령의 결정에 따라 국군이 질서 유지 차원에서 출동하는 것은 헌법상의 의무 이행인데'},
#  {'text': '@josesvt1 @jayr_562 don’t subtweet like females'},
#  {'text': 'Lol I remember when I was called a whale 😂'},
#  {'text': "@48mate Judy's ponytail died for our sins https://t.co/0bTWFP0cPQ"},
#  {'text': '@Shhhhhh_Shush r u fucking serious omg!'},
#  {'text': 'The sun really be draining af.'},
#  {'text': '@Gmoebmoekareful every single baller has had this moment bruh loooooool'},
#  {'text': 'TEST_GEO_Hierarchy: e517866f-e881-4597-ab96-b180872a2a54'},
#  {'text': 'TEST_GEO_Hierarchy: 8c7b5946-58fa-4094-8000-3f458ed68d63'},
#  {'text': '24 🔥♥️ https://t.co/iMvzMYIBZW'},
#  {'text': 'You can never go wrong with chicken and guacamole.'},
#  {'text': 'wikihow to roll a backwood'},
#  {'text': 'This man got me out here ...bald headed n shit. I dunno where we are...'},
#  {'text': '@CryptoWildWest This is exactly what I was talking about. I see these opportunities regularly, but I’m not confident in my strategy yet'},
#  {'text': '@GoddessVienna @SextPanther Actually kinda hot.'},
#  {'text': 'IM SO SICK AND FUCKEN TIRED OF PEOPLES BULLSHIT'},
#  {'text': 'Dad level approaching dangerous new heights... https://t.co/aKHaHjX5xP'},
#  {'text': '이를 쿠데타로 모는 자가 있다. 좌익이 폭동할 때 군대가 구경만 하도록 함으로써 반공자유민주주의 체제가 무너지도록 하기 위한 예행연습 아닌가? (국민행동본부'},
#  {'text': '@superNATorious @Perrico_Querico I shit you not it only looks like this on camera, in person it’s like white/gray LOL'},
#  {'text': '@blueauthority Ojalá.'},
#  {'text': '@Stammy @googlephotos damn. this is incredible'},
#  {'text': 'You can support black women and \nFuck white girls \nDon’t let anybody tell u different brother'},
#  {'text': '@C_3C_3 The assertion that he was coordinating with the Russians was an outright lie. Without that lie the warrant would have been denied.'},
#  {'text': '9. 이왕 수사단이 만들어졌으니 가장 먼저 이 문건의 유출경위를 조사하여 엄단하라!10. 戰時(전시)에는 국군이 국민을 보호하지만 平時(평시)엔 국민이 국군을 지켜\n야 한다. ‘국군을 모독하는 불순세력’으로부터 국군을 지키자! (국민행동본부)'},
#  {'text': '@jfrosh_10 Slap yourself'},
#  {'text': '@WhoopiGoldberg \n\nChose #Love https://t.co/8CaqYlDiUB'},
#  {'text': '@michaelgat Omagosh!'},
#  {'text': 'mexican dads at the grocery store will never not try &amp; school me on beer at the beer aisle'},
#  {'text': '@JizzaRaw ahhh thank you!'},
#  {'text': '@BackTheCops 🙏'},
#  {'text': 'Another season of Nikki being the prettiest one. #LHHH https://t.co/h1wS7j5C2b'},
#  {'text': '@dopeiamana @JaimesSthp JAJAJAJAJAJAJA “ese no es el que nos iba levar?!?” Ya bien pedo 😂😂😂'},
#  {'text': '@jfcmang @darrenrue @whatisnudoin i rocking with darren on this one, tyreke evans shit was crazy too'},
#  {'text': 'There’s literally a shirtless crazy dude on this train pacing around and yet @metrolosangeles is doing nothing???? SHOCKER'},
#  {'text': '“seems like everybody is a dick without you baby”'},
#  {'text': 'not dead just ignoring you lol'},
#  {'text': 'My favorite character of #RHONY is sober Luanne in that wig and my favorite character of #RHOC is Shannon’s dog.'},
#  {'text': '@dukhanomore @Carola2hope Comenzaré pronto.'},
#  {'text': "@ispypanda You have to win me first. \nAnd I'm not an easy prize to get. \nBut if you do... \nyou'll get a prize well worth  keeping."},
#  {'text': 'i’m hungry'},
#  {'text': '@adorabobo agot have u gone to an gs open practice, asking for science'},
#  {'text': '@SarahPalinUSA SMH 🤦\u200d♂️'},
#  {'text': 'I got really happy because I thought Castle Rock came out today but no it comes out Wednesday. #ugh'},
#  {'text': 'iPhone 📱 \niPod 📱 \niPad 🖥\n\niPaid 😒'},
#  {'text': '@thecocoamama @ayanatheoracle @kriscia_mar Lmao def not worried about shawty.'},
#  {'text': '@yvonne_pacheco @DerickMorales45 Soraya would disagree too'},
#  {'text': '@TMZ @CraigSargent55 😂😂😂😂😂😂😂😂😂😂😂'},
#  {'text': 'Wonder if my girl is down to go to Sonics one day 🤔🤔🤔🤔'},
#  {'text': '@eelyzv 😭😭😭'},
#  {'text': '김 형석 연대명예교수, "이 정부는 170년전 마르크스주의자 들의 정의와 평등 의식을 갖고있다." "마르크스 주의자들이 정권을 잡으면 지난정권은 모두 적폐로 몰아부친다" 이나라 썪은 지식인들속의 군계일학!(Gyung Won)'},
#  {'text': '"Different Strokes For Different Folks." ~ Sly and the Family Stone'},
#  {'text': '@BJordann96 ❤️❤️❤️😘'},
#  {'text': '@phaserbeam Awwww let’s go!'},
#  {'text': 'You gotta learn how to align with her energy, not destroy it.'},
#  {'text': "@BradMossEsq He's certain that he's going to get a pardon &amp; he's probably right."},
#  {'text': 'songina givin me ASMR 😋😴'},
#  {'text': '@beverlylove @Iaurakinney Our roommate @yurigods drew it !!'},
#  {'text': 'Today was so weird. I hope tomorrow’s better'},
#  {'text': 'wow, raising canes did not live up to the hype i had expected. https://t.co/7swALqC3Pn'},
#  {'text': "@ElaErica That and what's best for Titan. Which is why he's keeping Chad on as CEO."},
#  {'text': '@johanamichellee  https://t.co/MHbyw718fx'},
#  {'text': '@sofiaxvh i think you pregnant or not pregnant, it’s still over for us :/ lol you’re pregnant and badder than i’ll ever be 😂'},
#  {'text': '@Enzolover63 Sucks when people make baseless generalisations about you doesnt it? Arent you being a bit over-sensitive?'},
#  {'text': 'My friends I’ll go to war for them just like I know they’ll do the same for me'},
#  {'text': '@DonCheadle No one says thE “N” word that easy that hasn’t said it many times before'},
#  {'text': '@alessandrodak I love uuuuu'},
#  {'text': 'long live is the greatest taylor song of all time I don’t make the rules'},
#  {'text': '#fuck12 https://t.co/CmstCFpMqH'},
#  {'text': '@hormiga 1 + 2 = Hamster 🐹 ?'},
#  {'text': '@tatyanaluvscats Hot pic but sis, this is a clusterfuck of a post lmao.'},
#  {'text': 'Lol I remember when I was called a whale 😂'},
#  {'text': "@48mate Judy's ponytail died for our sins https://t.co/0bTWFP0cPQ"},
#  {'text': '"It takes longer than you think to write a good tweet," I pomped at the kid as I looked down to realize I hadn\'t attached the photo'},
#  {'text': "@DerProzess That's your rotten life, Lalenia. \nהפסדתי על זה התערבות."},
#  {'text': '@AdiJoseph @AdrianChen Queens is the last real section of New York \nQueens Asian diaspora food is flames'},
#  {'text': 'Going into this first date with LOW expectations https://t.co/l3ti0SJ962'},
#  {'text': '@zestitude A Leo eh? Both my kids are Leos.'},
#  {'text': '@MLBONFOX @Pirates Y’all need to start losing so you can trade Vazquez to the Dodgers'},
#  {'text': 'verdugo’s first at bat after being called up and he has to face seranthony dominguez'},
#  {'text': '🤑 https://t.co/IuDhHdGgw7'},
#  {'text': '@BillRosemann @MarvelChampions @Marvel @MarvelGames Best storyline was always between she and Rogue.'},
#  {'text': '"It takes longer than you think to write a good tweet," I pomped at the kid as I looked down to realize I hadn\'t attached the photo'},
#  {'text': '9. 이왕 수사단이 만들어졌으니 가장 먼저 이 문건의 유출경위를 조사하여 엄단하라!10. 戰時(전시)에는 국군이 국민을 보호하지만 平時(평시)엔 국민이 국군을 지켜\n야 한다. ‘국군을 모독하는 불순세력’으로부터 국군을 지키자! (국민행동본부)'},
#  {'text': '@jfrosh_10 Slap yourself'},
#  {'text': '@WhoopiGoldberg \n\nChose #Love https://t.co/8CaqYlDiUB'},
#  {'text': '@michaelgat Omagosh!'},
#  {'text': 'mexican dads at the grocery store will never not try &amp; school me on beer at the beer aisle'},
#  {'text': '@JizzaRaw ahhh thank you!'},
#  {'text': '@BackTheCops 🙏'},
#  {'text': 'Another season of Nikki being the prettiest one. #LHHH https://t.co/h1wS7j5C2b'},
#  {'text': '@dopeiamana @JaimesSthp JAJAJAJAJAJAJA “ese no es el que nos iba levar?!?” Ya bien pedo 😂😂😂'},
#  {'text': '@jfcmang @darrenrue @whatisnudoin i rocking with darren on this one, tyreke evans shit was crazy too'},
#  {'text': 'There’s literally a shirtless crazy dude on this train pacing around and yet @metrolosangeles is doing nothing???? SHOCKER'},
#  {'text': '“seems like everybody is a dick without you baby”'},
#  {'text': 'not dead just ignoring you lol'},
#  {'text': 'My favorite character of #RHONY is sober Luanne in that wig and my favorite character of #RHOC is Shannon’s dog.'},
#  {'text': '@dukhanomore @Carola2hope Comenzaré pronto.'},
#  {'text': "@ispypanda You have to win me first. \nAnd I'm not an easy prize to get. \nBut if you do... \nyou'll get a prize well worth  keeping."},
#  {'text': 'i’m hungry'},
#  {'text': '@adorabobo agot have u gone to an gs open practice, asking for science'},
#  {'text': '@SarahPalinUSA SMH 🤦\u200d♂️'},
#  {'text': 'I got really happy because I thought Castle Rock came out today but no it comes out Wednesday. #ugh'},
#  {'text': 'iPhone 📱 \niPod 📱 \niPad 🖥\n\niPaid 😒'},
#  {'text': '@thecocoamama @ayanatheoracle @kriscia_mar Lmao def not worried about shawty.'},
#  {'text': '@yvonne_pacheco @DerickMorales45 Soraya would disagree too'},
#  {'text': '@TMZ @CraigSargent55 😂😂😂😂😂😂😂😂😂😂😂'},
#  {'text': 'Wonder if my girl is down to go to Sonics one day 🤔🤔🤔🤔'},
#  {'text': '@eelyzv 😭😭😭'},
#  {'text': '김 형석 연대명예교수, "이 정부는 170년전 마르크스주의자 들의 정의와 평등 의식을 갖고있다." "마르크스 주의자들이 정권을 잡으면 지난정권은 모두 적폐로 몰아부친다" 이나라 썪은 지식인들속의 군계일학!(Gyung Won)'},
#  {'text': '"Different Strokes For Different Folks." ~ Sly and the Family Stone'},
#  {'text': '@BJordann96 ❤️❤️❤️😘'},
#  {'text': 'Not looking forward to having to drive my dad’s truck to the airport to pick them up😭'},
#  {'text': '@OfficialPWG 🙌🏾🙌🏾 https://t.co/iqeU50FsDu'},
#  {'text': 'I’m only getting in where I fit in'},
#  {'text': 'Flex. https://t.co/SexJFdIpIv'},
#  {'text': 'Childish gambino - Summertime 🔥'},
#  {'text': '@nxylo_ Dis how i’ll look Forever LMAO https://t.co/aIva9lK5X8'},
#  {'text': 'ugh he’s so precious 😢'},
#  {'text': '@aaronjmate @jvgraz It has nothing to do with progressive values.'},
#  {'text': 'no lobby com meu irmão só p pegar wifi'},
#  {'text': 'Poor Nilsa 😂😂 @nillythesquid #mtvfloribamashore @495prods @floribamashore #TheDishWish'},
#  {'text': 'U people really need go stop with the\n6ix9ine is a pedophile nonsense \nAll u look stupid'},
#  {'text': 'There’s a dude on Jeopardy who has a cat named Merv Griffin.'},
#  {'text': '@JoshuaH83934845 Resourceful!'},
#  {'text': '@adorabobo agoat have u ever gone to an fs open practice- asking for science'},
#  {'text': 'pamukha ba naman saakin WOW'},
#  {'text': '@kelatequila_ Omg 🤣🤣🤣🤣'},
#  {'text': 'Rocking my Almost Innocent matte lipstick! Perfect mauve!! @SmoakCosmetics  get it get it get it now!!! https://t.co/el8mLVmbWU'},
#  {'text': ':( https://t.co/qUrj1SphPN'},
#  {'text': '@cmonstah And Stravinsky at the Hollywood Bowl in 1966 https://t.co/XSI3wKvWfi'},
#  {'text': 'Like ugh, go do that shit somewhere else BUT my Expo Line 🙄'},
#  {'text': "@HotYoungBriley Will you bring him to @JQuasto and @DarthWatts bday party plz? \nEven if you can't make it?"},
#  {'text': 'That was a great match #RAW #WWE #WWERAW'},
#  {'text': 'just Be'},
#  {'text': '@kristinepohl unfortunately, some ppl still have that attitude I guess'},
#  {'text': 'PRO TIP: When you wanna start an uprising to overthrow the government and instate your own rule, PRINT 👏 ENOUGH 👏 PAMPHLETS 👏'},
#  {'text': 'when the mosquitos biting everyone around me but me \U0001f92a🤠'},
#  {'text': '#NewProfiIePic https://t.co/L9nkgHNqjQ'},
#  {'text': 'GOD I LOVE MY GIRL. THANK U GOD'},
#  {'text': 'I’ve never been so glad to be back in LA'},
#  {'text': 'Change is good, change is good, change is good.'},
#  {'text': 'This world is something else man..'},
#  {'text': 'well it took a lifetime, but being a #hippie (#yippie) is finally popular again #peace #love &amp; Yippie!!! https://t.co/tTEWEGZObt'},
#  {'text': '@JayeLee But if Russia backs Iran...........it’s only a matter of time.'},
#  {'text': 'https://t.co/RcnGHROTsU'},
#  {'text': '@MildlyAmused It’s not in the top three of the franchise, if that helps. Rebecca Ferguson is criminally underused.'},
#  {'text': 'my dog walking around the pool with a life vest is the funniest thing i’ve ever seen 😂😂....he got style tho'},
#  {'text': 'Be very careful of what you put on your mind'},
#  {'text': '@naimaism Ive honestly cut down on the amount of wild clapbacks to people coming creZy i just ignore now'},
#  {'text': 'Succession is a great show, but the opening title sequence blows'},
#  {'text': 'My sister just won me tickets for the Barcelona vs Tottenham this Saturday. I’m stocked !'},
#  {'text': '@davidhogg111 @Twitter  @SecretService'},
#  {'text': '@camnomadic I don’t know how anyone can eat there'},
#  {'text': 'this heat is a hate crime'},
#  {'text': '@Victorisaurus Apart from the incredible heat and rampant overtaking of bugs it’s pretty cool'},
#  {'text': '@princessui29 (＞人＜;)'},
#  {'text': '5033 Topanga Canyon Boulevard https://t.co/hrmYh3cCZO'},
#  {'text': '@mahooroh like a full sleeve of tattoos, but it doesn’t go past my forearm lol'},
#  {'text': '@igobyweicks Lmfaooo I prefer better for myself I’m good luv enjoy 😭😭😭'},
#  {'text': '@KhamiWolves @TrexPushups Really?! Wow that’s crazy. It’s like the best place to have a picnic.'},
#  {'text': '@milkstrology Thinking of you. Maxi and I are sorry for your loss bb.'},
#  {'text': '@Gunewop you would like this place ..'},
#  {'text': '@krassenstein @SharonSharonh10 How far in the closet is HE?'},
#  {'text': '@ThomasBeautyy Ok we want more. We want a novel or documentary please and thank you.'},
#  {'text': '@RealADebus Come on give us an example!'},
#  {'text': 'Anyone have max royal recruits and want a #1 finish?'},
#  {'text': '@Zigmanfreud @USGA Local qualifiers next year. Good luck'},
#  {'text': '*Bae does anything.\n\nMe: Why are you soooo Fine!!!😍 https://t.co/hzN7VUhLaq'},
#  {'text': '@drebm Ainda sem previsão :/'},
#  {'text': 'Boys are literally disgusting'},
#  {'text': 'if I’m eating, my besties eating too. Tf u think this is'},
#  {'text': '@Mikalbitterman1 You forgot about Post Malone'},
#  {'text': 'it is what it is https://t.co/VzkhkSLNfM'},
#  {'text': 'How’s everyone’s Monday been?'},
#  {'text': 'Yesterday’s shoot was a success! 3 videos in one night. On to the next night 1AM-6AM 🎥 💪'},
#  {'text': '@mtehuitz Praised be the witch memes are our gay agenda.'},
#  {'text': '@renesperez Nope'},
#  {'text': '대한민국 vs 미합중국 인구 0.5억 vs 3.3억 청와대 vs 백악관 비서실 직원수 480명 vs 377명 이건 분명 미친 나라 아닌가? 근데, 인원이 부족해서 더 늘린다고?(Yeong Kook Jeong)'},
#  {'text': 'I hope no one saw that'},
#  {'text': 'i just finished 90210 for the 9th time hahahaha i love this show so much'},
#  {'text': '@RichSqueezy After'},
#  {'text': 'TEST_GEO_Hierarchy: 8150b462-b130-4423-90e2-498c17dded51'},
#  {'text': 'TEST_GEO_Hierarchy: da545f09-0cb8-4921-82b4-1b08ef9b82e4'},
#  {'text': '@jerweber He’s a dingleberry'},
#  {'text': '@MeganTaylor122 Thanks meg❤️'},
#  {'text': 'Ya guey 😭😭😭😂😂'},
#  {'text': '&amp; now that it’s over I’ll never be sober🎶'},
#  {'text': '@TomiLaffly Shhh don’t tell, I love NY 😸'},
#  {'text': 'Back at home post gorge and Russian River pizza and beer. https://t.co/WHQzWawzSc'},
#  {'text': 'Tacos 🌮Mood for life'},
#  {'text': 'se tem uma coisa q eu sou apaixonada é por do sol'},
#  {'text': '@BodhiSimpson Yes, not in another person!'},
#  {'text': '@RaiderThomas Yes they are'},
#  {'text': '#Dodgers Win https://t.co/Yf6HnKISbt'},
#  {'text': '@markzoomy Forced'},
#  {'text': 'Just finished dinner at nearly 8pm and I still have to workout how the fuck do people fit all this shit into one life?'},
#  {'text': 'Don’t focus on what you see focus on what HE said, worry less pray more 🙏🏾'},
#  {'text': '@virginiatodd Thank you!'},
#  {'text': '@BodhiSimpson Yes, not in another person!'},
#  {'text': '@RaiderThomas Yes they are'},
#  {'text': '#Dodgers Win https://t.co/Yf6HnKISbt'},
#  {'text': '@markzoomy Forced'},
#  {'text': 'Just finished dinner at nearly 8pm and I still have to workout how the fuck do people fit all this shit into one life?'},
#  {'text': 'Don’t focus on what you see focus on what HE said, worry less pray more 🙏🏾'},
#  {'text': '@virginiatodd Thank you!'},
#  {'text': '리센퉁 싱가폴총리는 가슴에 싱가폴기와 태극기 뱃지를 달았다. 그러나 문씨는 태극기 뱃지를 안 달았다. 정말 누군가를 향한 문씨의 충성심이 놀라울 정도다. 문씨가 저렇게 충성을 바치는 누군가는 과연 어느놈인가??? (Sting)'},
#  {'text': '@gaquitaine Terrible! I always thought it was a mistake for Assange to go to the Ecuadorian Embassy.'},
#  {'text': 'JESUS TAKE THE WHEEL'},
#  {'text': 'Thank you, @Phillies!'},
#  {'text': '“Is it possible to fall in love with someone through a picture?”\n \n             Yes don’t look at them..'},
#  {'text': 'Consistency.'},
#  {'text': '6-5 DODGERS!!!'},
#  {'text': '~ // street photography thread'},
#  {'text': '-@FamilyGuyonFOX battle royal\n#SDCC2018 \n#abc7eyewitness https://t.co/vDnBxbYtil'},
#  {'text': '@charliekirk11 @Kamballs Wow!'},
#  {'text': 'If that was Princess real friend she would’ve handled moniece for her while she pregnant 🤷🏾\u200d♀️#LHHH'},
#  {'text': 'Pujols is back!'},
#  {'text': '#GetUninvitedIn4Words\nIs the food vegan? #BanFactoryFarming 🌱 https://t.co/Kw6CSkCvYx'},
#  {'text': '@kellyanneken Thanks baby'},
#  {'text': 'I can’t wait for my mama to come visit me because I need some pinto beans (no cornbread), peach cobbler, and smothered chicken w/rice'},
#  {'text': 'issa vibe. https://t.co/b3dCRX6j0o'},
#  {'text': 'Great Hustle VERDUGO! #Dodgers take the lead 6-5 top of the 9th'},
#  {'text': 'Never in my life id thought id be a gym addict but i am😂'},
#  {'text': 'Dog moms winning'},
#  {'text': '@___nope____ @okjxjo He did three in LA just last week.\nOne at almost every EDC Vegas at Sunrise. Pretty easy to catch one.'},
#  {'text': '@Island_Moreau @christinadirkes @serathegamble But... 😂 https://t.co/703IC5sUYF'},
#  {'text': 'Nothing better then laying in some freshly washed bed sheets 💜💞'},
#  {'text': '@goddessjasmine0  https://t.co/6yMjN7mj4a'},
#  {'text': '@shannonmarsico Lmfaoooooo'},
#  {'text': '@iamdestinyyb 😂'},
#  {'text': 'Verdugo be like...  #Dodgers https://t.co/WlBS6x9nyd'},
#  {'text': '@Marc_Normandin I was hedging in case I forgot one but liquid swords is one of the few others in this conversation'},
#  {'text': 'Buying a @Tesla is exactly the same as having a baby... Everyone says congratulations and wants to see pics/ facetime. 👶🏼 @elonmusk'},
#  {'text': 'I just wanna do hood rat shit with my friends'},
#  {'text': '@ayyeeandie Come and visit us in the hood'},
#  {'text': '@JoshuaYehl Hahahah I’ll have to practice for the next convention'},
#  {'text': '@emelyxxi Thank you 😌'},
#  {'text': 'I don’t care imma bad bitch when it come down to it I can wear my own hair 🤷\u200d♀️😘'},
#  {'text': '@FirstGentleman Julius got that wagon.'},
#  {'text': 'Twitter forever on night mode🌙✨'},
#  {'text': 'Hella pictures of couples I have seen recently, they look like they are siblings and it’s weird asf 😂😂'},
#  {'text': '@DonaldHermann He is the best. He lets me take alllll kinds of pics, no matter how long it takes me. 💕'},
#  {'text': '#tiffanyandco #necklace #pendants #gift #alphabet https://t.co/vkEalZB4nK'},
#  {'text': 'I hate people who want to match with trash weed 🙄'},
#  {'text': '@realDonaldTrump We need everybody Lou.'},
#  {'text': 'When I have a problem I can’t fix.\nGod: https://t.co/gRVY9wLaq9'},
#  {'text': 'that’s my dawg'},
#  {'text': "@EVincentelli @zinoman I'm hooked."},
#  {'text': '@MoshiMinecraft8 The order of the letters is referenced'},
#  {'text': 'Whew chile...'},
#  {'text': 'Tough game! But good way to start the series @Dodgers 😎'},
#  {'text': 'I listen to nothing but bangers https://t.co/FS9g0VlNjQ'},
#  {'text': '@dergigi Bah!'},
#  {'text': '@GeekyJuuu DJBDBDKXHD IM SO GLAD'},
#  {'text': '@ashley_white03 yeah girl I auditioned for it 😂'},
#  {'text': '@MattSiegel25 @sultansofpa @MLB ur right F 😔'},
#  {'text': '@ClintSmithIII Can you imagine the smell of the books'},
#  {'text': 'about to go munch on some fireee tacos ! 🌮'},
#  {'text': 'Dodgers showing great patience at the plate, and getting that W!'},
#  {'text': '@BodhiSimpson Yes, not in another person!'},
#  {'text': '#Dodgers Win https://t.co/Yf6HnKISbt'},
#  {'text': '@RaiderThomas Yes they are'},
#  {'text': '@markzoomy Forced'},
#  {'text': 'Just finished dinner at nearly 8pm and I still have to workout how the fuck do people fit all this shit into one life?'},
#  {'text': 'Don’t focus on what you see focus on what HE said, worry less pray more 🙏🏾'},
#  {'text': '@virginiatodd Thank you!'},
#  {'text': 'Alright it’s time for me to stop playing and lose weight'},
#  {'text': '@wellheythereMJ Oh shit forgot that existed'},
#  {'text': 'Weeds is hilarious i don’t know how i wasn’t watching this before.'},
#  {'text': '@K_DUBB_80 @RaideretteQT @JDsGaffilin Like you knew that he would now!'},
#  {'text': '@xoaaron_ @swerve_squirrel Mix some fire sauce with the cheese and dip them lol'},
#  {'text': '🚨 Anthony Rizzo pitching alert 🚨'},
#  {'text': 'Damn this match sucks'},
#  {'text': '@Pflax1 @Jalopnik @CitiBikeNYC But I don’t work for @Jalopnik.'},
#  {'text': 'What’s a drip to a faucet? 🚰 https://t.co/E9qLz3T6p5'},
#  {'text': '@2mh_g 有難うメイ😋帰ったら遊んでやー！'},
#  {'text': 'Bro, Dulces de La Rosa (makers of Mazapán) just followed me on IG. Day is made.'},
#  {'text': 'Never a doubt (sarcasms)  @kenleyjansen74'},
#  {'text': "@iccwomen why aren't the Semifinal matches not on TV or Streaming?"},
#  {'text': 'you feel the vibe it’s contagious \U0001f92d'},
#  {'text': 'Before anyone comes for me I mean like tone and slim down my legs a tad'},
#  {'text': '@Maguirre90 Hahaha I’ve never been called average...that was a first 😂'},
#  {'text': '@AmandiOnAir @realDonaldTrump Lots of people hear that lots of times. Hope your sources are reliable'},
#  {'text': '@danblackroyd ???'},
#  {'text': '@SarahKSilverman A BIG cost!'},
#  {'text': '@OrinamiSmile @SKIIIIIIIN No'},
#  {'text': 'A full workday... https://t.co/0aUJJvnYsB'},
#  {'text': '@carlreiner 🙏'},
#  {'text': '@a_son_of_a_gunn @GreaterAKL Cost'},
#  {'text': 'what’s the most chill thing u ever did?'},
#  {'text': 'Dodgers -160 💰💰\nPersonal play Braves Ml💰💰\nWhite Sox up 1-0'},
#  {'text': '@ChristianaAristotleKennedyOnassisiIII: This is my name. i am Aristotle and Onassis Daughter, and in lucid of JFK for the myth, only.'},
#  {'text': '@fal1026 Man is on the ifone 😤'},
#  {'text': '@SaltyCorpse @JulietsRosez As do I.'},
#  {'text': 'These days without sex memes are hilarious'},
#  {'text': 'Not to sound like a old person but like this yeti really keepin my water cold 😭'},
#  {'text': 'You got this @ARizzo44 !'},
#  {'text': '@Sorry2BotherYou Afro wig and a can coke will be my Halloween costume btw great movie 🍿'},
#  {'text': 'Karma 2. • @DaveEast https://t.co/Kgl8eOglBm'},
#  {'text': "@CynthiaHaskin14 And if God is on Gabi's side I'd want Him to be on Abby's side if she were to get back at Gabi. She won't, but still."},
#  {'text': '@V_nss_A and joosey'},
#  {'text': '@Dodgers  https://t.co/pRJZcEsOaX'},
#  {'text': 'Halloween is so big for Sophia. She puts so much thought into her costume.'},
#  {'text': "Whoever decided to close the wall connecting Pink to Victoria's Secret in the Glendale Galleria can catch these hands..."},
#  {'text': 'how cute is my son with his nana 😭❤️ https://t.co/gYHvXGZW5P'},
#  {'text': 'https://t.co/4kjSztf1m1'},
#  {'text': '@lildarlinjay Thank you. We do try and make it a good space for all.'},
#  {'text': '@virginiatodd What’s your Venmo'},
#  {'text': '@LieslieMontelon I’ll trade ya 😍'},
#  {'text': 'Work views at Warner Bros. S/o to all the @SHO_Shameless fans out there https://t.co/X9oG3sdSaj'},
#  {'text': 'Where are my tissues #TheBachlorette'},
#  {'text': 'Tbh fam I just wanna eat and back to sleep...'},
#  {'text': '@twitter what do I need to do to get verified? You’re the last one 🤗💪'},
#  {'text': 'AHHHHHHHHHHHHH'},
#  {'text': 'When I show my kids the math problems I had to do in middle school:\nMy Daughters: https://t.co/rtRzydYYXd'},
#  {'text': '@macnchz61 @tcmilbert @killernj13 @WhiteHouse @POTUS Great question. I bet he answers tan suit and Dijon mustard'},
#  {'text': "I swear on all that is holy that if the Dbacks can't get 1 run off a catcher or 1st Baseman PITCHING, then they are dead to me."},
#  {'text': '"The biggest risk is not taking any risk." ~ Mark Zuckerberg'},
#  {'text': 'Can’t wait to be back on tour'},
#  {'text': '@bernardscott3 Nice I can’t wait to check out your guitar playing skills'},
#  {'text': 'And if he drinks IPA’s and looks like Gumby well.... good luck Charlie'},
#  {'text': '@USC_Athletics Let’s train ✌🏾 @TelemundoSports vamos ⚽️!! #celebritytrainer #fitness https://t.co/5wQ6RR6TFq'},
#  {'text': 'When Blake said he’s the type of person that looks for a reason to stay not a reason leave.... i lost it #TheBachelerette'},
#  {'text': '@realDonaldTrump @JudicialWatch Why when they keep finding witches?? I can’t wait for the warlock \U0001f92e'},
#  {'text': 'She’s one of a kind talaga 😭💕 https://t.co/7a8aYZnfma'},
#  {'text': '@SarahKSilverman How about the cost of an Uber to your place and one back in time to walk and feed my dogs in the morning ?'},
#  {'text': '@V_nss_A @bot106  https://t.co/bZuttzMNLz'},
#  {'text': '@pizzahut On second thought, you guys sent me the wrong pizza and I got pineapple on top of my pizza😡😡😡'},
#  {'text': '@pbetsy22 @keljdm14 @AyesHavit @team2494 @FiredFBIBoss @StephenMilIer @realDonaldTrump Seems like I can only reply to certain posts.'},
#  {'text': '@AshOldfield 😂😂😂'},
#  {'text': 'She legit just said she can’t be Pocahontas’s because her hair isn’t straight but then was like “never mind you can buy me a wig” 🤣🙈🤣'},
#  {'text': '@EddieFWoodsdale Lol— there are chord diagrams because I know my fingers look kinda weird'},
#  {'text': 'Once you see something you can’t forget it'},
#  {'text': 'you committed now huh? i guess i can’t hit it like i hit it now huh?'},
#  {'text': 'Shout out to @sugarfish for giving us 1 pair of chopsticks in a delivery for 3 people.'},
#  {'text': '@Micklanna @R1ck79 @CharlieBuscemi @AmandiOnAir @realDonaldTrump @marcorubio Will not happen.'},
#  {'text': 'An abstract extract ... from what? https://t.co/PAI7u7Lvp7'},
#  {'text': 'I’m glad Becca told him he’s too good to be true #theBachelorette'},
#  {'text': "@blackcatt44 Let's keep the ball rolling!"},
#  {'text': '@LydiaCornell Love this I went to an outdoor theater in Hollywood to watch this with my bff a couple weeks ago @Jaime_Allen  #SaveFerris 😍'},
#  {'text': 'You be with a nigga everyday 😭😂 he at yo house you at his and they still find time to do stupid shit like howwwwwwwwwww make it make sense'},
#  {'text': 'Just landed Mary Jane my puxxy‼️‼️‼️‼️'},
#  {'text': 'Watch how I switch up'},
#  {'text': '@son_of_nevelle Example? Just curious lol'},
#  {'text': 'Numéro un 🔥⚽️🏆 @paulpogba https://t.co/57YObnCW9n'},
#  {'text': '@natashavc  https://t.co/vtRC7hLAug'},
#  {'text': 'If you chilling with yo bitch I can come a fuck you both'},
#  {'text': 'Me: I’m so hungry, I could eat a horse\n\nAlso me (2hrs later): shit. I forgot to eat'},
#  {'text': 'I’m ready 👑 @KingJames https://t.co/bdOfomlvZc'},
#  {'text': "@GJOH29 Well for what it's worth, we just played the best team in the NL East.  The fact that we could get this W at all is kind of amazing."},
#  {'text': 'Literally everyday'},
#  {'text': '@jaydaruiiz I’ve seen a F*CKING ANGEL HAZIBWWKSJSO https://t.co/5vXydnqcoS'},
#  {'text': '@TaylorTomasello Wtf is all over the dash 😂'},
#  {'text': '@DankJenks_ It’s so pretty !'},
#  {'text': '.... are the Orioles.... good?'},
#  {'text': 'im about to cope my LANY tickets again (‘:'},
#  {'text': '@RHeathervaughn The good hate. ✌️'},
#  {'text': 'My mama made a star'},
#  {'text': 'TEST_GEO_Hierarchy: 9758bd24-46db-400b-86ce-60a64fbc7acc'},
#  {'text': 'TEST_GEO_Hierarchy: f12bdee6-bf4b-4975-b82f-3636f0864782'},
#  {'text': 'i deadass need a legit #sugardaddy like fr fr hmu daddies \U0001f92a'},
#  {'text': '@Zhandratika fish and chips!'},
#  {'text': 'And if he drinks IPA’s religiously and looks like “Gumby” well... good luck Charlie.'},
#  {'text': 'Loved the live IG make up tutorial video earlier, Regine. 😎👌'},
#  {'text': '"There\'s something happening hear... what it is isn\'t exactly clear." ~ Buffalo Springfield'},
#  {'text': '@thesethbishop im about to say it.,. i don’t care that i broke ur elbow https://t.co/Harc6woq52'},
#  {'text': 'Rizzo on the mound?! Now I have seen it all haha. Era:0. Go Cubs! https://t.co/igdm67AI4h'},
#  {'text': '@BodhiSimpson Yes, not in another person!'},
#  {'text': '@RaiderThomas Yes they are'},
#  {'text': '@AdrianChen PEOPLE DO IT ALLL THE TIME'},
#  {'text': '#Dodgers Win https://t.co/Yf6HnKISbt'},
#  {'text': '@markzoomy Forced'},
#  {'text': 'Just finished dinner at nearly 8pm and I still have to workout how the fuck do people fit all this shit into one life?'},
#  {'text': 'Don’t focus on what you see focus on what HE said, worry less pray more 🙏🏾'},
#  {'text': '@virginiatodd Thank you!'},
#  {'text': 'cookies!'},
#  {'text': '@Maguirre90 Hahahahaha it’s okay. I don’t take them well anyway.'},
#  {'text': '@AmaliaFer1 Es buenísima. Gracias!'},
#  {'text': '@Twitter 😂😂'},
#  {'text': '@Comic_Con home sweet home ...(almost) so until next year #SDCC we will miss you 😘 https://t.co/alvltAY4a3'},
#  {'text': '#Hexagonianforlife'},
#  {'text': '@RSchonhiutt You look so happy lately! I’m glad to see it ✨'},
#  {'text': "@Smokey___420 Yup. DEAD. I'm personally going to Phoenix and cursing them on their own soil. ✍🏼. I'm 100% serious about this."},
#  {'text': '@keatsmalone Fuck 😂😂😂'},
#  {'text': '@evan_b And losing to the Padres of all teams. The Mets continue to be in the spirit of giving. Nice stadium tho.'},
#  {'text': '@ziegler_md MRIaculous'},
#  {'text': 'i love the movie over board so much !!'},
#  {'text': '@transistor 買ってきましたー！'},
#  {'text': 'omg is this real omg https://t.co/WMLWQwoB0S'},
#  {'text': 'KICKBACK 10 PM?'},
#  {'text': '#dodgers'},
#  {'text': 'I hope she saves it though haha 😂'},
#  {'text': 'y’all really out here calling full rapists “problematic”? cardi b casually using the word dyke is problematic, rape is like actually evil???'},
#  {'text': '@AlwaysActions  https://t.co/8FT3I113Eg'},
#  {'text': 'Planning this weekend for Kait was a lot of work but well worth the work. Special thanks to @TheYenmaster to helping me set it up right.'},
#  {'text': 'I’d rather be full of tacos than emotions.'},
#  {'text': '@StealthBeth 😘😘😘'},
#  {'text': 'Thank god im living life cause that’s what’s mean the most to me'},
#  {'text': 'Hacia dónde debo voltear?'},
#  {'text': 'Craig Kimbrel unable to handle the ORIOLES?!\n\ncmon now'},
#  {'text': "Yeah she fine but I ain't impressed."},
#  {'text': '@mysonear We won, BTW, in case u haven,t seen it yet! 😂💙⚾️'},
#  {'text': '@YOMPitsCameron You’re mean'},
#  {'text': "@DOLSON_N_GABANA I didn't."},
#  {'text': 'Question time :                                           If Cinderella’s shoe fit perfectly, then why did it fell off ? 😴'},
#  {'text': '@Pantone294 GOT the W. https://t.co/WU12ZVGFfi'},
#  {'text': '@SheNeedsJayR Better be Waffle House'},
#  {'text': '@Amb_Kardash Facts sis lmao'},
#  {'text': 'growing my hair  i’m tired of getting haircuts'},
#  {'text': '@TucanCRC Rajado esos pilotos y ese avión! chuzo el Hercules!'},
#  {'text': 'I give what I receive'},
#  {'text': '@ahruhxx @edjmin Their legend lothar matthaus had a picture with Putin and no one said anything.'},
#  {'text': 'My roommate just told me John Gold died and I am crushed. Who else is going to show me the best doro wat in LA?'},
#  {'text': 'The paletero is NEVER around when you need him.'},
#  {'text': '@JusticetheSmith @whitneythefilm It is a horror film with music.'},
# ...
#  {'text': 'Live fast die young bad girls do it well'},
#  {'text': 'basic filtersssss https://t.co/j8I3m92qEp'},
#  {'text': '#LOVE https://t.co/3dE87JirJF'},
#  {'text': '@realDonaldTrump The only thing that happened was it highlighted the corruption'},
#  {'text': '@PrinceHAK33M @WestsideFoe_ Everything you said expect insert Trinidad James.'},
#  {'text': 'https://t.co/q1IMdxrFPm'},
#  {'text': '@yateman990 Me too'},
#  {'text': 'How do I always end up with random scratches all over me??'},
#  {'text': '@BaldBryan Hard to type this tweet wearing these gloves (fingers get chilly with the AC blasting)'},
#  {'text': '@DaniGeorge_ @ShotLonsert Can confirm, we gave em hell.'},
#  {'text': '@thekenzietaylor @InkedAngels @MyFreeCams Thank you sweetie 😘'},
#  {'text': '@timmotoh Some might consider it a TOOMAH...'},
#  {'text': '@PHILIPmANDERSON @garyvee @AnotherlyNews Yes sir!'},
#  {'text': 'Some people can’t be fully happy. They always have to find something to complain about.'},
#  {'text': '@Neighborhood_93 I’m ghetto then because I drench my pizza. 🤷🏽\u200d♀️😂'},
#  {'text': '@krassenstein Boycott Michigan in every way! No conventions, no biz dealings, no vacays there. Nothing. Michigan’s a pariah.'},
#  {'text': 'Whatevs this was a good tweet lmao'},
#  {'text': '@DarkFalcon89 @InkedAngels @MyFreeCams Thank you so much'},
#  {'text': 'first image from “nocturnal valley drives”\n\nday two of production: complete #NVDsummer 🌙 https://t.co/fVAGD0j9WA'},
#  {'text': '@DavidYankovich @joncoopertweets To Iranian Leader:. ONE GOOD PISS PARTY AND YOURE OFF THE HOOK. #peetape #goldenshowers @aravosis'},
#  {'text': '@nickhautman shit - I probably ate an entire bag of the xtra cheddar this week 😳'},
#  {'text': 'Imagine a pedialyte raspado 🍧'},
#  {'text': '@emicheltyler love dilfsofdisneyland 💕'},
#  {'text': "@BeeHaven007 Nat Sherman's, perhaps?"},
#  {'text': '@chyneeezy I’m just here for entertainment'},
#  {'text': 'I can’t believe ppl bitch about hxc kids not liking ska punk and other dumb genres I have no interest in who the fuck cares lol'},
#  {'text': 'I want a Sunday kind of love 💘'},
#  {'text': '@dktrogers The left is counting on the young female socialist’s agenda to beat the President!! Hold that thought!!'},
#  {'text': "@Violet_Monroe @InkedAngels @MyFreeCams Thank you sweetie 😘 you're awesome"},
#  {'text': 'やっと落ちこんのったよ。 https://t.co/Dv7vH8JYC4'},
#  {'text': 'The Lakers is turning into the Hood Nuggets. When they had Melo, A.I., J.R. Smith, and Kenyon Martin Hahaha'},
#  {'text': '@NahRocky @CatsGoMyao'},
#  {'text': '@realDonaldTrump Still a lie. Now you’re down to giving us used lies. We demand fresh only'},
#  {'text': "Love and take care of yourself. Don't forget that 🙏🏾"},
#  {'text': 'How is R Kelly still able to generate headlines that don’t include “arrested”?'},
#  {'text': '@grlalx @mdudas #OldPro'},
#  {'text': 'mano eu fico chocada como essas crianças de hoje em dia são tão mean cara, fico muito triste com essas histórias 💔😭'},
#  {'text': 'Dibs on the band name “Sanchez Doesn’t Hustle” https://t.co/MuErqsT976'},
#  {'text': "I don't wanna work grrrr"},
#  {'text': 'I’ll never say goodbye to the next person I fall in love with....'},
#  {'text': 'Working on a memoir - A Limber Winemonger: The Early Years.'},
#  {'text': '@dorirave  https://t.co/M0bjsmidQ4'},
#  {'text': '@zachjsanders HELL YEAH HEADASS'},
#  {'text': '@CaptainBadazz hey are you still on here? Let me know if you get this! ❤️'},
#  {'text': 'Need a friend to go to Disney and concerts with 😭'},
#  {'text': '@CrisLovesH I am so incredibly proud of you!!♥️'},
#  {'text': '@RodriguezbLeo Let’s go with @anacucumbers'},
#  {'text': '#MoneyAMovie for richer for richer'},
#  {'text': '@dieg0bregon lmfao i feel this'},
#  {'text': '@Clippers89 Because the Trump administration fucking sucks...'},
#  {'text': 'I keep my mouth closed you niggas &amp; bitches talk too much'},
#  {'text': 'What did Kimberly do to her face #lhhhollywood'},
#  {'text': 'https://t.co/mkLjjIPIUD'},
#  {'text': '@GregBen2511925 Would love to help but there is nothing I would be able to do.'},
#  {'text': 'Just a small reminder that #paddington2 is still rated 100% on Rotten Tomatoes. https://t.co/HHpu2WVLMM'},
#  {'text': 'Read my shit and don’t reply ...Fuck you! 😂'},
#  {'text': '@MikeCovarruvias Nah, I can handle it 💪🏽'},
#  {'text': '@osugm08 @TSearcaigh @realDonaldTrump #gutfeeling like that are usually based on #prejudices'},
#  {'text': '@RadFinch @AnnaBellPeaksXX @InkedAngels @MyFreeCams All my choice are from my experiences and what i have seen'},
#  {'text': '@1776Stonewall @themanfronUNCLE LMFAO 😆'},
#  {'text': 'Why I always gotta be the one to catch it on the low tho'},
#  {'text': 'See you soon Phoenix. I look forward to cursing you on your own soil, for eternity. ✍🏼DTM'},
#  {'text': 'Thank God for reggae nights and your girlfriends to keep you up in times of heartbreak . 👯\u200d♀️♥️ https://t.co/XRa3nNgS2S'},
#  {'text': 'damn.......'},
#  {'text': 'Last Day Tomorrow 🛩'},
#  {'text': '@KAPSLok89  https://t.co/zbGbhjXbow'},
#  {'text': '@Yurr_Gasont OKAY, got me SHOOOOOOOK ALREADY‼️\n“the strength of my complexion” https://t.co/FUkeCuTMvt'},
#  {'text': "@RadioITEL @blackbird9_9 All i know is you've been kicked out of 109 countries since the 1st century cause no one could stand ya!"},
#  {'text': '@BernieSanders Are you a Democrat?'},
#  {'text': 'Leos do it the best ! Leos wya ? Its our time 💋'},
#  {'text': '@HesNot4Evrybody You ready again'},
#  {'text': '@Shetropicc I’m a mixing engineer dm me'},
#  {'text': 'Somebody actually woke me up from a nap to get on here.'},
#  {'text': 'My Amy and chase howled for the first time today I swear I Shed a tear 😭'},
#  {'text': 'think BIG. - advice from a drunk guy at the bar that’ll i’ll carry the rest of my of life'},
#  {'text': 'mood https://t.co/ti2y3LGuWc'},
#  {'text': 'Just made this https://t.co/Lw6iNLi1xE'},
#  {'text': 'I have no idea why I do this to myself.'},
#  {'text': "@Justin1194 @InkedAwards There's a lot more tattoo girls now as well"},
#  {'text': 'Don’t trust these niggas get tested.'},
#  {'text': '@etherealcabello I love for Camila'},
#  {'text': '@annamelissa that’s crazy'},
#  {'text': 'shot for me x drake 😪'},
#  {'text': '@wicked_ninja123 @InkedAwards Thank you'},
#  {'text': 'Tomorrow’s going to be poppin @aileenalvarezz 💃🏻'},
#  {'text': 'Can it be cold again so i can wear my sweatshirt/sweaters 😕'},
#  {'text': '@JesseKellyDC Oh yeah.'},
#  {'text': '@anaacortez_  https://t.co/4sBnRfV9mu'},
#  {'text': 'Work ,  night school, side hustle ,gym, nap wake up ...'},
#  {'text': 'I’ve always wanted to play poker and be able to say this line in a British accent https://t.co/IYdg1RrrGk'},
#  {'text': '@betaworldpeace brutal'},
#  {'text': '@Patrickesque But @SenGillibrand should have stfu...she is part of problem. Block me I do not care because that is the truth.'},
#  {'text': '@thespookynessa liar'},
#  {'text': 'Hollywood: 8:00pm: sunset'},
#  {'text': 'Fucc it I’m go have a good time tonight'},
#  {'text': 'If you don’t follow me on Twitter I’m unfollowing you.'},
#  {'text': 'I swear I’m nicer than my resting bitch face would have you believe https://t.co/o4xxuyvxdu'},
#  {'text': 'Been telling mom to switch over😭 https://t.co/qcBxOezhHC'},
#  {'text': 'This is what I deal with... https://t.co/9M6TCv28Uo'},
#  {'text': '@jamietavernini i love and miss you jamie :( 💖💖'},
#  {'text': '@imlitafbro Eso si es amor del bueno ❤️'},
#  {'text': 'I ain’t got no patience for folks who either ain’t fam or ain’t bout money conversations. I’m after a bag.'},
#  {'text': "@perfectcosima NOOO STOP TOO CUTE!!! What's their name???"},
#  {'text': 'Glendale: 8:00pm: sunset'},
#  {'text': '@DanielBrathor thank you !'},
#  {'text': 'Y’all be taking pills 😳'},
#  {'text': '@animturnbull There’s about 5 markers on that whole suit!'},
#  {'text': '@court_hansen Debating'},
#  {'text': 'I almost cussed out a rich white man today'},
#  {'text': '@PauliFansclub Dios mío 😮 https://t.co/O0KOX44AGr'},
#  {'text': 'And I would be traveling to Oakland this weekend 😪'},
#  {'text': 'Watching Nels Cline and Jim Campilongo tonight 🎸😜🤘🤠🚨👌👌😎💀⚡️🙌🏻🙌🏻🙌🏻'},
#  {'text': 'Los Angeles: 7:59pm: sunset'},
#  {'text': '@Cindtrillella a QUEEN. but nah he liked the track and he was coo😂😂😂'},
#  {'text': '@mjcp @Richard_Schiff You 😊'},
#  {'text': 'Let me waste your time.'},
#  {'text': '@BeeHaven007 They sell those at the bodega up the street. \nNot as popular as American Spirit,  but a lot of Latinas enjoy them.'},
#  {'text': "Still can't believe Mr.Butler passed away 💔"},
#  {'text': '@bujourn Yup'},
#  {'text': 'Dude said #PBM 🤣🤣🤣🤣'},
#  {'text': 'Bitches who hate me/ don’t like me over a nigga are stupid !'},
#  {'text': 'QUEER SQUAD https://t.co/EOGLkqvn6l'},
#  {'text': 'ITS A SUCH THING AS A FAGGOT NIGGA TOO.........'},
#  {'text': '@vanessamolinaa_ Fat ass Chico 😂'},
#  {'text': '@shanedawson Me'},
#  {'text': '@HJBosch21 @RWhittall @FutbolIntellect True he’s always nervous around me it’s how I like him'},
#  {'text': "@timmotoh It's growing on an Amerikan ..."},
#  {'text': 'i truly love seeing other people genuinely happy and smiling out of joy!!!! like yesss, live ya best life!!!🦋🌞💫'},
#  {'text': '@100TAlpaca I want something'},
#  {'text': 'https://t.co/b9iBGQlIO1'},
#  {'text': 'It’s so hot'},
#  {'text': 'I’m hungry'},
#  {'text': '@g_libertino Thank you. That’s what I wanted. Lots of guys were reaching for total fliers while I tried to find vets with roles.'},
#  {'text': 'it’s still #LongLiveDavey'},
#  {'text': "I'm convinced every gild named liz is just a big nose bitch👀💁"},
#  {'text': 'My husband just told me about Kim Guilfoyle and Trump Jr.  makes me feel better knowing the Prez has her in his camp. #KAG2020'},
#  {'text': '@_prettymuchyeah OMG it looks so ridiculous LOL I put it on and Scott just laughed at me and told me to go to a mirror'},
#  {'text': '@G0newiththeWend @JarredMack Only in public restrooms'},
#  {'text': 'https://t.co/ZgOt2hxjMk'},
#  {'text': '@clipperdarrell 5 years'},
#  {'text': '&amp; im not makin my shit private like for what lol'},
#  {'text': '#Toronto is truly an AMAZING city!  #TorontoShooting #TorontoStrong #DanforthAttack https://t.co/Nahk6UJMz4 @analysisnytimes'},
#  {'text': '@EddieOrozco21 his change looked particularly good today. You guys have a convo recently? Hope all is well, Sir.'},
#  {'text': '@ottergawd @katrinasivad'},
#  {'text': 'I feel like this is said a lot....but Im definitely leaving my heart in California ❤️🌴'},
#  {'text': "@TheComicConGuy @EXXXOTICA Yes the last one I'd in NJ. First week of November. Just check out their website"},
#  {'text': '@MikeDeneen1 @RoseLuke13 @Reflog_18 He couldn’t stop Hines Ward. He was the “Batman” to his his Bane'},
#  {'text': '50 is a FORCE!!!!!!!!!!!!'},
#  {'text': '@TheWhaleBaby @djcati i don’t deserve it....,, this greatest honor of my life, but I’ll accept it..,,,,,,,,,('},
#  {'text': '@oskeyramos proud of you!💓'},
#  {'text': '@xRed0ctobeRx A lady never tells!'},
#  {'text': '@abc7anabel How are you? :)'},
#  {'text': '@RealMuckmaker @DisabledResist A target for the business end of my Louisville Slugger.'},
#  {'text': '@Jake_Blackson Bing is so bad at translating lmao'},
#  {'text': "Mamma Mia! except it's Rubber Johnny"},
#  {'text': '##RUNFATBOYRUN IS ONNNNN'},
#  {'text': 'Going live on @UnapologeticAMC was fun THANX @UnapologeticAMC  @aishatyler @AMC_TV @margaretcho @MiraSorvino @TramellTillman #unapologetic'},
#  {'text': 'I’m that fucker that you tell can’t do something and will go and do it just to prove a point'},
#  {'text': '@_creaturelives @agnosticpsycho1 Yes me too!! You gave the best hugs all weekend it made me so happy every time we saw you 💗'},
#  {'text': '@JeremyDempe @mattszy  https://t.co/VvkKojV2jI'},
#  {'text': 'thERES A SHAKE SHACK IN THIS AIRPORT DO I GO'},
#  {'text': 'El Domingo Nuestra Hermosa Cumple Años @soypaulinagoto Y Lo Chistoso Ese Mismo Día Cumplo Años También ❤️❤️ https://t.co/k8ZZhsg2tx'},
#  {'text': 'i dont fuck like its a sport, im boring lmfao'},
#  {'text': '@Worldliberation Really?'},
#  {'text': 'Muthafukkers that train boxing more than 1 hour a day....I got a whole new respect for you fukkers.'},
#  {'text': 'Back and forth and back and forth..👏\n\n#RAW'},
#  {'text': '@Mosqvich @verymoody @reillybrennan I fully endorse motorcycles. Bicycles, too.'},
#  {'text': '@steveucnlive It just gets better &amp; better! https://t.co/CKDcES4PGv'},
#  {'text': '@JinkxMonsoon Atta Girl!'},
#  {'text': 'One nigga since we was 15/16 lmao so u kno I’m extraaaaaaaa deadhomies'},
#  {'text': 'The fact that Sonny wants the job as CEO of Titan back knowing what he did is a little disturbing. #Days'},
#  {'text': 'From when Mike &amp; I first got him, to now! Our baby’s gettin big fast!!😩💙 https://t.co/Aq9dVzb7BR'},
#  {'text': 'Santa Monica: 8:00pm: sunset'},
#  {'text': '@PJWalsh24 😡'},
#  {'text': 'Something called: FLOATING TACOS from Senor Chef Galvin, hailing from Rough &amp; Ready, CA. 🌮❤️🥗 https://t.co/gFLD1f6yc2'},
#  {'text': '@HesNot4Evrybody Hit my line'},
#  {'text': '@TheAnimeGoddess @PulpRiotHair Guess it’s time for some Vainglory Purple :)'},
#  {'text': 'S/O @AserTheGreat always'},
#  {'text': 'I need some Waffle House in my life rn 😩'},
#  {'text': '@shhhavannah ILY ❤️❤️❤️'},
#  {'text': 'Damn best decision I’ve done all day. Log out of Instagram.'},
#  {'text': '@BabyFaceCheech Prime example'},
#  {'text': 'I’m that fucker that doesn’t give up no matter how bad shit gets or is getting'},
#  {'text': '@Jerryyvill @jrdnwllms I’m cryingggggggg lmfao'},
#  {'text': 'Ouch.'},
#  {'text': '@OANN Sounds good all are corrupt'},
#  {'text': '@KakiMiller1 @gaagee0406 @jwheels74 Yup! https://t.co/bhEJ5ZYtL6'},
#  {'text': 'temperature down 92°F -&gt; 88°F\nhumidity down 43% -&gt; 25%\nwind 5mph -&gt; 6mph'},
#  {'text': '@AdrianChen And there’s always a random mall with fuego \nAnd a new weird Mediterranean fusion chain popping up'},
#  {'text': 'Some dude is outside scream singing all of the cookout classics and it’s horrible but amazing 😂'},
#  {'text': '@braddie22 @AngelinaCastroX Information will be coming out soon. We are located looking into locations'},
#  {'text': '@brontayy u got gr8 friends #modelotime'},
#  {'text': 'Mood just hit a all time low'},
#  {'text': '@Necation @amirahamawe'},
#  {'text': "@MLBONFOX EPIC game.  Tension 'til the end!"},
#  {'text': '@77Medellin weaaaak'},
#  {'text': 'My driver just asked me how tall I am with and without my shoes on so I just wanted to tell y’all I love you before I get murdered 😘'},
#  {'text': '@MeghanMcCain @SherriEShepherd Yeah she seems to be sitting on her ass and eating bon bons.'},
#  {'text': 'The Same Thing Over &amp; Over Gets irritating Gotta Know When To Fall Back'},
#  {'text': 'Hey, I’m delayed two hours in Sacramento until 11pm local time. I’ll be home at 3am as of right now. https://t.co/2FcmjSqiqM'},
#  {'text': 'I snapped 🤙🏻💛 https://t.co/kdtpLVkN6O'},
#  {'text': 'This is what I deal with and honestly, I don’t mind. Lol @Make_Up_Junkie https://t.co/wAz49vINrX'},
#  {'text': '@bigmike88283166 @jorse2646 @ducksfan2007 @SEX_Overlord @VNAgirls Thank you'},
#  {'text': '@Novaesoul @EmilyRB @MissyElspeth 💔💔💔'},
#  {'text': 'I’m that fucker that knows he the best as what he does , ain’t no one better !'},
#  {'text': '@LeftSentThis I hope they fry this creep'},
#  {'text': 'https://t.co/kVHmZZsQ9k'},
#  {'text': '"In theory, there is no difference between theory and practice. In practice there is." ~ Yogi Berra'},
#  {'text': 'listening to Christmas music and dancing alone in my underwear 4ever'},
#  {'text': 'Already tearing up thinking about seeing Cal Pal walk down the aisle next week 😅💕👰🏽'},
#  {'text': 'Every time I think I like someone they pull something lame lol'},
#  {'text': '@Novaesoul @EmilyRB @MissyElspeth I’ve found quite a few victims just by looking on the Internet. There are many many more I am sure.'},
#  {'text': '@Lilian @gabrielintica qué buenísima frase.'},
#  {'text': 'I’m feeling another World Series for my babies 😈 @Dodgers'},
#  {'text': 'Am I the only one who hasn’t been to boiling crab?'},
#  {'text': '@EmilyRB @Novaesoul @MissyElspeth 💔'},
#  {'text': 'Sometimes I RT Shit so other people see and become outrage. I got like 5 people that shit work perfect for everytime...'},
#  ...]

# %%
len(tweet_text)
# Out:
# 198466

# %%
tweet_text.head()
# Out:
#                                                 text
# 0  Can’t wait to go home and play video games alr...
# 1  Can’t wait to go home and play video games alr...
# 2                         ya https://t.co/ZOjRvdvOFB
# 3                                  Let’s go #Dodgers
# 4  “Chunky peanut butter is rough on the teeth, l...

# %%
tweet_text.text = tweet_text.text.str.replace('http\S+|www.\S+', '', case=False)

# %%
tweet_text.text
# Out:
# 0         Can’t wait to go home and play video games alr...
# 1         Can’t wait to go home and play video games alr...
# 2                                                       ya
# 3                                         Let’s go #Dodgers
# 4         “Chunky peanut butter is rough on the teeth, l...
# 5
# 6                Another shit show!! \nGO O'S!!\n#DeadBirds
# 7                                @SPRinNYC Me, a Capricorn.
# 8                                                       ya
# 9                                         Let’s go #Dodgers
# 10        “Chunky peanut butter is rough on the teeth, l...
# 11
# 12               Another shit show!! \nGO O'S!!\n#DeadBirds
# 13                               @SPRinNYC Me, a Capricorn.
# 14                                                      ya
# 15                                      @TheRynheart Kookoo
# 16        @The_Trump_Train @realDonaldTrump We need cand...
# 17                    I'm going through a lot right now....
# 18
# 19        There’s nothing I want to do more than to slee...
# 20        There's a pile of shit on the table at work. I...
# 21        5년간 23조 쓰고 4대강 보 남긴 이명박과 13개월간 34조 쓰고 최악의 실업률,...
# 22                @_MartinWeiss Please use it in a sentence
# 23        @jackeryinc I would use Jackery products in Jo...
# 24        @arboldepaz La parte final es la más graciosa....
# 25        @bryadee_ Damn man that mean imma have to fight 😭
# 26                                Defintion of a lil bitch
# 27              @jessiekaiser @JoseyPickering @pansaralance
# 28        RAWAYANA PA EL ALMA Y CULTURA PROFETICA PA LA ...
# 29                           Zooted is such a catchy song 😭
#                                 ...
# 198436    @alyssa_castano I toured the american airstrea...
# 198437                    @vbndmoney happy birthday old man
# 198438                             That is all!  Carry on!
# 198439    @NowellKern @ScottMStedman Trump is a traitor....
# 198440    The game we've all been waiting for, @LAFC and...
# 198441    I feel like everyone I’ve been today all I hea...
# 198442              @TonyFergusonXT @danawhite 🖕🏼@danawhite
# 198443       That was damn near the coolest shit I ever saw
# 198444          Y’all have gone MAD in our mentions.\n-Pavy
# 198445                                         On one cares
# 198446                         @itsrhyda_ 😂 you gotta FT me
# 198447                 Losing again. \nGO O'S!! \n#BirdGang
# 198448                         @NowellKern @ScottMStedman
# 198449    TEST_GEO_Hierarchy: e29dff6a-c06d-407e-8099-01...
# 198450    TEST_GEO_Hierarchy: b015edbe-a897-4849-bc64-c9...
# 198451                               The Art of Letting Go.
# 198452                                                   🤙
# 198453                                         No one cares
# 198454                                     me when im drunk
# 198455                    big pizza energy\n\n@Pizzaoki 🍕👅
# 198456                   @BCsuz Happy birthday suzpuz!!!!❣️
# 198457    @NowellKern @ScottMStedman I love his new pain...
# 198458    Caved and bought the Halo Master Chief collect...
# 198459    Thoughts and prayers to everyone in my hometow...
# 198460                   Aquí andamos. We ready   #LAFCvLA
# 198461                           I understand you Esther.😫💔
# 198462                         @NowellKern @ScottMStedman
# 198463                                   damn I’m awkward 😩
# 198464                     FUCKED UP BETOND ALL REASONNNNN
# 198465                      ohh how the tables have turned
# Name: text, Length: 198466, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(tweet_text.text)
word_occurence = tfidf.transform(tweet_text.text).todense()

# %%
word_occurence.shape

# %%
words = tfidf.get_feature_names()
word_sample = random.sample(words, 20)
word_occurence_m = pd.DataFrame(word_occurence, columns=words)
word_occurence_m[word_sample].head()

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation(n_topics=10, learning_method='batch')
lda.fit(word_occurence)

# %%
lda_df = pd.DataFrame(lda.components_, columns=words).T

# %%
def filter_topic(lda_df, index, threshold):
    return (lda_df[lda_df[index] > threshold][index]
            .sort_values(ascending=False))

# %%
filter_topic(lda_df, 0, 2)

# %%
filter_topic(lda_df, 1, 2)

# %%
filter_topic(lda_df, 2, 2)

# %%
filter_topic(lda_df, 3, 2)

# %%
filter_topic(lda_df, 4, 2)

# %%
filter_topic(lda_df, 5, 2)

# %%
filter_topic(lda_df, 6, 2)

# %%
filter_topic(lda_df, 7, 2)
