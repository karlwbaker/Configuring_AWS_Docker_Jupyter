# %% [markdown]
# Use `pip` to install `twitter`.
#
# Use "!" at beginning of line.

# %%
! pip install twitter
# Out:
# Requirement already satisfied: twitter in /opt/conda/lib/python3.6/site-packages (1.18.0)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /opt/conda/lib/python3.6/site-packages (10.0.1)

# %% [markdown]
# Import `TwitterStream` and `OAuth` from `twitter`.

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
from twitter import TwitterStream, OAuth

# %% [markdown]
# ### `oauth`
# Authentication protocols

# %% [markdown]
# Create a new object called `oauth` using `OAuth`.
#
#     OAuth(token, token_secret, consumer_key, consumer_secret)

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
token = '2379975860-fvNwQM9Kk9bL4A6AyTNdGSSJAKuE9dDnTEISg3q' # access token
token_secret = 'JPYjiwcOWnGy6nuJEvDt9owkKaQvXcvN2sryA8wl3kQxL' # access token secre
consumer_key = 'iJm4IBd4wmfJJjOTvQiMOrEXf'
consumer_secret = '9a4G3kwY1w3OmekWdmQGMo2nxLuxTxttjDQrfsRuvI9rUv29O6'   # API secret

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
oauth = OAuth(token, token_secret, consumer_key, consumer_secret)

# %% [markdown]
# Create a new object called `twitter_stream` using `TwitterStream`.
#
# Use the argument `auth=oauth` referencing the `oauth` object you just made.

# %% [markdown]
# ### `twitter_stream`

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
twitter_stream = TwitterStream(auth= oauth)

# %% [markdown]
# ### `bounding_box`

# %% [markdown]
# Create a string called `bounding_box`. The string should contain the geo-coordinates of a bounding box separated by commas. These values are for Santa Monica:
#
#     -118.5137323688,34.0001996344,-118.4702449172,34.0331651696
#
# You can make your own here: https://boundingbox.klokantech.com. Be sure to specify CSV RAW to get the values in this format.
#
# ![](https://www.evernote.com/l/AAH3H9KGE6hD9JpPJPFncw09exRyoYSid5IB/image.png)

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
bounding_box = '-118.5137323688,34.0001996344,-118.4702449172,34.0331651696' # Santa Monica

# %% [markdown]
# ### `tweet_iterator`
#
# Create an object called `tweet_iterator`.
#
# 1. Use `twitter_stream`. # NOT the full fire hose. Maybe 1 in 8 tweets. Paid subscription for ALL tweets.
# 1. Apply `.statuses` to grab statuses.
# 1. Apply a `.filter()` with the argument `locations=bounding_box`.

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
tweet_iterator = (twitter_stream
                  .statuses
                  .filter(locations=bounding_box))

# %%
type(tweet_iterator)
tweet_iterator
# Out:
# <generator object TwitterJSONIter.__iter__ at 0x7f7334162f68>

# %% [markdown]
# Get the next value from the `tweet_iterator` and store it as the variable `this_tweet`.

# %%
this_tweet = next(tweet_iterator)
this_tweet
# Out:
# {'created_at': 'Fri Jul 20 07:40:57 +0000 2018',
#  'id': 1020211946757402625,
#  'id_str': '1020211946757402625',
#  'text': 'https://t.co/3ZcNeM4PH4',
#  'display_text_range': [0, 0],
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1368753673,
#   'id_str': '1368753673',
#   'name': 'Arthur',
#   'screen_name': 'ArthurBerberyan',
#   'location': None,
#   'url': None,
#   'description': None,
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 157,
#   'friends_count': 152,
#   'listed_count': 1,
#   'favourites_count': 3039,
#   'statuses_count': 2738,
#   'created_at': 'Sun Apr 21 05:29:28 +0000 2013',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1020180591281487873/hG4sEN0n_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1020180591281487873/hG4sEN0n_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1368753673/1532065206',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': {'id': '3b77caf94bfc81fe',
#   'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#   'place_type': 'city',
#   'name': 'Los Angeles',
#   'full_name': 'Los Angeles, CA',
#   'country_code': 'US',
#   'country': 'United States',
#   'bounding_box': {'type': 'Polygon',
#    'coordinates': [[[-118.668404, 33.704538],
#      [-118.668404, 34.337041],
#      [-118.155409, 34.337041],
#      [-118.155409, 33.704538]]]},
#   'attributes': {}},
#  'contributors': None,
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [],
#   'symbols': [],
#   'media': [{'id': 1020211942252634112,
#     'id_str': '1020211942252634112',
#     'indices': [0, 23],
#     'media_url': 'http://pbs.twimg.com/media/DiiFWy2UYAAOBg4.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DiiFWy2UYAAOBg4.jpg',
#     'url': 'https://t.co/3ZcNeM4PH4',
#     'display_url': 'pic.twitter.com/3ZcNeM4PH4',
#     'expanded_url': 'https://twitter.com/ArthurBerberyan/status/1020211946757402625/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 345, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 608, 'h': 1200, 'resize': 'fit'},
#      'large': {'w': 1038, 'h': 2048, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1020211942252634112,
#     'id_str': '1020211942252634112',
#     'indices': [0, 23],
#     'media_url': 'http://pbs.twimg.com/media/DiiFWy2UYAAOBg4.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DiiFWy2UYAAOBg4.jpg',
#     'url': 'https://t.co/3ZcNeM4PH4',
#     'display_url': 'pic.twitter.com/3ZcNeM4PH4',
#     'expanded_url': 'https://twitter.com/ArthurBerberyan/status/1020211946757402625/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 345, 'h': 680, 'resize': 'fit'},
#      'medium': {'w': 608, 'h': 1200, 'resize': 'fit'},
#      'large': {'w': 1038, 'h': 2048, 'resize': 'fit'}}}]},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'und',
#  'timestamp_ms': '1532072457385'}

# %% [markdown]
# What is the type of `this_tweet`?

# %%
type(this_tweet)
# Out:
# twitter.api.TwitterDictResponse

# %% [markdown]
# Display the keys of `this_tweet`.

# %%
this_tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'display_text_range', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'extended_entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms'])

# %% [markdown]
# Display the `text` and `user` of `this_tweet`.

# %%
this_tweet['text']
# Out:
# 'https://t.co/3ZcNeM4PH4'

# %%
this_tweet['user']
# Out:
# {'id': 1368753673,
#  'id_str': '1368753673',
#  'name': 'Arthur',
#  'screen_name': 'ArthurBerberyan',
#  'location': None,
#  'url': None,
#  'description': None,
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 157,
#  'friends_count': 152,
#  'listed_count': 1,
#  'favourites_count': 3039,
#  'statuses_count': 2738,
#  'created_at': 'Sun Apr 21 05:29:28 +0000 2013',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1020180591281487873/hG4sEN0n_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1020180591281487873/hG4sEN0n_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1368753673/1532065206',
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %% [markdown]
# ## Collect Tweets
#
# Create an empty list called `tweets`.
#
# Use a `for`-loop to collect ten tweets and add them to this list.

# %%
type(tweet_iterator)

# %%
tweets = []
for i in range(10):
    tweets.append(next(tweet_iterator))

# %% [markdown]
# Display `tweets` in a DataFrame.

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
import pandas as pd

# %%
tweets_df = pd.DataFrame(tweets)
tweets_df
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Fri Jul 20 07:40:58 +0000 2018           [7, 140]
# 1         None        None  Fri Jul 20 07:40:59 +0000 2018                NaN
# 2         None        None  Fri Jul 20 07:41:01 +0000 2018                NaN
# 3         None        None  Fri Jul 20 07:41:02 +0000 2018                NaN
# 4         None        None  Fri Jul 20 07:41:02 +0000 2018                NaN
# 5         None        None  Fri Jul 20 07:41:03 +0000 2018           [23, 39]
# 6         None        None  Fri Jul 20 07:41:03 +0000 2018           [16, 36]
# 7         None        None  Fri Jul 20 07:41:03 +0000 2018            [0, 37]
# 8         None        None  Fri Jul 20 07:41:08 +0000 2018                NaN
# 9         None        None  Fri Jul 20 07:41:08 +0000 2018                NaN
#
#                                             entities  \
# 0  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 6  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 7  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 8  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 9  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                    extended_entities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  {'media': [{'id': 1020211963467464704, 'id_str...
# 8                                                NaN
# 9                                                NaN
#
#                                       extended_tweet  favorite_count  \
# 0  {'full_text': '@AHSFX We lived in the Murder H...               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3                                                NaN               0
# 4                                                NaN               0
# 5                                                NaN               0
# 6                                                NaN               0
# 7                                                NaN               0
# 8                                                NaN               0
# 9                                                NaN               0
#
#    favorited filter_level                        ...                          \
# 0      False          low                        ...
# 1      False          low                        ...
# 2      False          low                        ...
# 3      False          low                        ...
# 4      False          low                        ...
# 5      False          low                        ...
# 6      False          low                        ...
# 7      False          low                        ...
# 8      False          low                        ...
# 9      False          low                        ...
#
#   quoted_status_id_str                            quoted_status_permalink  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2  1020211803731636224  {'url': 'https://t.co/luZJerG8SH', 'expanded':...
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# 6                  NaN                                                NaN
# 7                  NaN                                                NaN
# 8                  NaN                                                NaN
# 9                  NaN                                                NaN
#
#   reply_count retweet_count  retweeted  \
# 0           0             0      False
# 1           0             0      False
# 2           0             0      False
# 3           0             0      False
# 4           0             0      False
# 5           0             0      False
# 6           0             0      False
# 7           0             0      False
# 8           0             0      False
# 9           0             0      False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# 6  <a href="http://twitter.com/#!/download/ipad" ...
# 7  <a href="http://twitter.com" rel="nofollow">Tw...
# 8  <a href="http://twitter.com" rel="nofollow">Tw...
# 9  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms  \
# 0  @AHSFX We lived in the Murder House\nWe escape...  1532072458842
# 1  I have the biggest headache and I feel like th...  1532072459224
# 2                                         3 for me 😬  1532072461169
# 3  I’m not sexually attracted to little boys who ...  1532072462460
# 4  Ok idk how I’m up rn. I be knocked by like 10p...  1532072462713
# 5            @doctorjasun @zaddynak Rather redundant  1532072463385
# 6               @lorraine @cher Cher is so damn cute  1532072463312
# 7  vou amanhecer na porta daquele parque https://...  1532072463952
# 8                           Keep an eye on this man.  1532072468497
# 9  Wow, @Taiki_Nulight ‘s set is slapping harder ...  1532072468583
#
#    truncated                                               user
# 0       True  {'id': 57062277, 'id_str': '57062277', 'name':...
# 1      False  {'id': 2788467172, 'id_str': '2788467172', 'na...
# 2      False  {'id': 191649388, 'id_str': '191649388', 'name...
# 3      False  {'id': 46316720, 'id_str': '46316720', 'name':...
# 4      False  {'id': 612148165, 'id_str': '612148165', 'name...
# 5      False  {'id': 16959643, 'id_str': '16959643', 'name':...
# 6      False  {'id': 831838198548484097, 'id_str': '83183819...
# 7      False  {'id': 25329707, 'id_str': '25329707', 'name':...
# 8      False  {'id': 1013193801546981376, 'id_str': '1013193...
# 9      False  {'id': 1279551192, 'id_str': '1279551192', 'na...
#
# [10 rows x 35 columns]

# %% [markdown]
# Display just the text of the tweets using DataFrame.

# %%
tweets_df['text']
# Out:
# 0    @AHSFX We lived in the Murder House\nWe escape...
# 1    I have the biggest headache and I feel like th...
# 2                                           3 for me 😬
# 3    I’m not sexually attracted to little boys who ...
# 4    Ok idk how I’m up rn. I be knocked by like 10p...
# 5              @doctorjasun @zaddynak Rather redundant
# 6                 @lorraine @cher Cher is so damn cute
# 7    vou amanhecer na porta daquele parque https://...
# 8                             Keep an eye on this man.
# 9    Wow, @Taiki_Nulight ‘s set is slapping harder ...
# Name: text, dtype: object

# %% [markdown]
# What is the type of `tweets`?

# %%
for obj in [tweets, tweet_iterator, tweets_df]:
    print(type(obj))
# Out:
# <class 'list'>
# <class 'generator'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Write a list comprehension to display the type of each of the objects in `tweets`.

# %%
[type(obj) for obj in tweets]
# Out:
# [twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse,
#  twitter.api.TwitterDictResponse]

# %% [markdown]
# Import the `json` library.

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
import json

# %% [markdown]
# Create an object called `tweets_string` using `json.dumps()`.
#
# Display the first 500 characters of this string.

# %%
tweets_string = json.dumps(tweets)
tweets_string[:500]
# Out:
# '[{"created_at": "Fri Jul 20 07:40:58 +0000 2018", "id": 1020211952868458497, "id_str": "1020211952868458497", "text": "@AHSFX We lived in the Murder House\\nWe escaped the Asylum \\nWe protected the Coven\\nWe got refunds for the Freak Show\\u2026 https://t.co/JvHJpm717h", "display_text_range": [7, 140], "source": "<a href=\\"http://twitter.com/download/iphone\\" rel=\\"nofollow\\">Twitter for iPhone</a>", "truncated": true, "in_reply_to_status_id": 1020205811484614656, "in_reply_to_status_id_str": "102'

# %% [markdown]
# ## Write Tweets to Disk
#
# Using this pattern
#
#     with open(filename_as_string, 'w') as outfile:
#         json.dump(python_object, outfile)
#
# write `tweets` to disk as json.

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
from datetime import datetime, date

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
def get_timestamp():
    timestamp_str = str(datetime.now())
    timestamp_str = (timestamp_str.replace(' ', '_')
                                  .replace('.', '-')
                                  .replace(':', '-'))
    return timestamp_str

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN
def write_tweets_to_disk(hundred_tweets):
    timestamp_str = get_timestamp()
    print('tweets_' + timestamp_str + '.json')
    with open('tweets_' + timestamp_str + '.json', 'w') as outfile:
        json.dump(hundred_tweets, outfile)

# %% [markdown]
# ## Read Tweets from Disk
#
# Using this pattern
#
#     with open(filename_as_string) as infile:
#         json_data=infile.read()
#         python_object_from_disk = json.loads(json_data)
#
# read the tweets from the json. Store them as `tweets_from_disk`.

# %%
with open('tweets.json') as infile:
    json_data = infile.read()
    tweets_from_disk = json.loads(json_data)

# %% [markdown]
# Display `tweets_from_disk` as a DataFrame.

# %%
tweets_from_disk_df = pd.DataFrame(tweets_from_disk)
tweets_from_disk_df
# Out:
#   contributors                                        coordinates  \
# 0         None  {'type': 'Point', 'coordinates': [-118.243, 34...
# 1         None                                               None
# 2         None                                               None
# 3         None                                               None
# 4         None                                               None
# 5         None                                               None
# 6         None                                               None
# 7         None  {'type': 'Point', 'coordinates': [-118.243, 34...
# 8         None                                               None
# 9         None                                               None
#
#                        created_at display_text_range  \
# 0  Fri Jul 20 03:12:57 +0000 2018                NaN
# 1  Fri Jul 20 03:12:58 +0000 2018                NaN
# 2  Fri Jul 20 03:12:56 +0000 2018            [0, 29]
# 3  Fri Jul 20 03:12:59 +0000 2018           [37, 58]
# 4  Fri Jul 20 03:13:00 +0000 2018            [0, 46]
# 5  Fri Jul 20 03:13:03 +0000 2018                NaN
# 6  Fri Jul 20 03:13:03 +0000 2018                NaN
# 7  Fri Jul 20 03:13:05 +0000 2018                NaN
# 8  Fri Jul 20 03:13:07 +0000 2018                NaN
# 9  Fri Jul 20 03:13:09 +0000 2018                NaN
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'caloforniadonuts', 'in...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 6  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 7  {'hashtags': [{'text': 'carwash', 'indices': [...
# 8  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 9  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                    extended_entities  \
# 0                                                NaN
# 1                                                NaN
# 2  {'media': [{'id': 1020144363731595264, 'id_str...
# 3                                                NaN
# 4  {'media': [{'id': 1020144508783116288, 'id_str...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3                                                NaN               0
# 4                                                NaN               0
# 5                                                NaN               0
# 6                                                NaN               0
# 7  {'full_text': '#carwash anyone? @cutelunastar ...               0
# 8                                                NaN               0
# 9                                                NaN               0
#
#    favorited filter_level                        ...                          \
# 0      False          low                        ...
# 1      False          low                        ...
# 2      False          low                        ...
# 3      False          low                        ...
# 4      False          low                        ...
# 5      False          low                        ...
# 6      False          low                        ...
# 7      False          low                        ...
# 8      False          low                        ...
# 9      False          low                        ...
#
#   quoted_status_id_str                            quoted_status_permalink  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# 6                  NaN                                                NaN
# 7                  NaN                                                NaN
# 8                  NaN                                                NaN
# 9   890170407587860482  {'url': 'https://t.co/0FGA2Ngqbo', 'expanded':...
#
#   reply_count retweet_count  retweeted  \
# 0           0             0      False
# 1           0             0      False
# 2           0             0      False
# 3           0             0      False
# 4           0             0      False
# 5           0             0      False
# 6           0             0      False
# 7           0             0      False
# 8           0             0      False
# 9           0             0      False
#
#                                               source  \
# 0  <a href="http://instagram.com" rel="nofollow">...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# 6  <a href="http://twitter.com/download/iphone" r...
# 7  <a href="http://instagram.com" rel="nofollow">...
# 8  <a href="http://twitter.com/download/iphone" r...
# 9  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms  \
# 0  #caloforniadonuts #donuts #losangeles @ Los An...  1532056377359
# 1                                 Onna dead Locsters  1532056378014
# 2  How’s coming to dinner mates? https://t.co/VDc...  1532056376858
# 3  @JDSalant @Davidlaz @realDonaldTrump It’s not ...  1532056379968
# 4  An evolution of @meechie_l and I 2012-2018 ☺️💖...  1532056380769
# 5  my vacay went by so fast but I spent every day...  1532056383546
# 6      I fucking love New Orleans gotta go back soon  1532056383483
# 7  #carwash anyone? @cutelunastar \nYou see ! In ...  1532056385949
# 8            why tf ice coffee make me so gassy 😞😞😞😞  1532056387846
# 9         Yo @tbp_tron come get your boy @Luiistbp 💀  1532056389662
#
#    truncated                                               user
# 0      False  {'id': 87829214, 'id_str': '87829214', 'name':...
# 1      False  {'id': 1183447392, 'id_str': '1183447392', 'na...
# 2      False  {'id': 1545729600, 'id_str': '1545729600', 'na...
# 3      False  {'id': 238259086, 'id_str': '238259086', 'name...
# 4      False  {'id': 46409130, 'id_str': '46409130', 'name':...
# 5      False  {'id': 725831378030338049, 'id_str': '72583137...
# 6      False  {'id': 482646991, 'id_str': '482646991', 'name...
# 7       True  {'id': 883298618, 'id_str': '883298618', 'name...
# 8      False  {'id': 3373026466, 'id_str': '3373026466', 'na...
# 9      False  {'id': 121902316, 'id_str': '121902316', 'name...
#
# [10 rows x 35 columns]

# %% [markdown]
# ### Collect as many tweets as possible 7/19 to 7/23

# %%
# RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN RUN

# from itertools import count

# counter = count(0)
counter = 0
hundred_tweets = []

while True:
    # next(counter)
    counter += 1
    
    # collect tweets
    hundred_tweets.append(next(tweet_iterator))
    
    # every 100 tweets write to disk, then continue
    if counter == 50:
        write_tweets_to_disk(hundred_tweets)
        # counter = count(0)
        counter = 0
        hundred_tweets = []
# Out:
# tweets_2018-07-20_07-42-57-957154.json
# tweets_2018-07-20_07-45-25-784394.json
# tweets_2018-07-20_07-46-59-028382.json
# tweets_2018-07-20_07-48-58-560786.json
# tweets_2018-07-20_07-50-45-318884.json
# tweets_2018-07-20_07-52-33-553029.json
# tweets_2018-07-20_07-54-30-726402.json
# tweets_2018-07-20_07-56-15-030690.json
# tweets_2018-07-20_07-58-22-920527.json
# tweets_2018-07-20_08-00-34-243983.json
# tweets_2018-07-20_08-02-31-345907.json
# tweets_2018-07-20_08-04-17-362847.json
# tweets_2018-07-20_08-06-07-025830.json
# tweets_2018-07-20_08-08-14-257226.json
# tweets_2018-07-20_08-10-24-108795.json
# tweets_2018-07-20_08-12-33-316989.json
# tweets_2018-07-20_08-15-10-440837.json
# tweets_2018-07-20_08-17-12-369005.json
# tweets_2018-07-20_08-20-04-324517.json
# tweets_2018-07-20_08-23-22-225468.json
# tweets_2018-07-20_08-25-34-760722.json
# tweets_2018-07-20_08-28-25-175149.json
# tweets_2018-07-20_08-31-22-617936.json
# tweets_2018-07-20_08-33-56-418895.json
# tweets_2018-07-20_08-36-58-160319.json
# tweets_2018-07-20_08-40-35-827248.json
# tweets_2018-07-20_08-43-23-801470.json
# tweets_2018-07-20_08-46-55-514916.json
# tweets_2018-07-20_08-50-53-268541.json
# tweets_2018-07-20_08-54-37-621647.json
# tweets_2018-07-20_08-57-27-251131.json
# tweets_2018-07-20_09-01-08-916584.json
# tweets_2018-07-20_09-04-32-779874.json
# tweets_2018-07-20_09-08-16-873416.json
# tweets_2018-07-20_09-11-46-349893.json
# tweets_2018-07-20_09-15-09-778751.json
# tweets_2018-07-20_09-18-24-068588.json
# tweets_2018-07-20_09-21-54-898844.json
# tweets_2018-07-20_09-25-20-406916.json
# tweets_2018-07-20_09-28-49-622524.json
# tweets_2018-07-20_09-32-56-712008.json
# tweets_2018-07-20_09-36-41-831363.json
# tweets_2018-07-20_09-40-17-240574.json
# tweets_2018-07-20_09-43-36-394335.json
# tweets_2018-07-20_09-48-16-838326.json
# tweets_2018-07-20_09-53-12-201102.json
# tweets_2018-07-20_09-58-01-907726.json
# tweets_2018-07-20_10-01-28-689592.json
